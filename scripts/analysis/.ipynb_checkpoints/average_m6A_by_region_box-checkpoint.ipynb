# %%
# Purpose of this script is to take in a .bam file and a .bed file and return %m6A across all regions in the .bam file
# in bin increments.
__author__ = "Yuri Malina"
__contact__ = "ymalina@berkeley.edu"
__copyright__ = "The Meyer Lab, UC Berkeley"
__credits__ = [""]
__date__ = "2/6/2023"
__deprecated__ = False
__status__ = "In development"
__version__ = "0.0.1"

# %%
import pandas as pd
#import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
import pysam
import random
from scipy import stats
# install tabix with:
# apt-get install tabix

# %%
### Configurations
m6A_thresh = 129 #default is 129
mC_thresh = 129 #default is 129
coreNum = 96 # cores to use

## Bed file configurations:
sample_source = "type" # "chr_type" or "type" or "chromosome"
sampleName = ["CHROMOSOME_I", "CHROMOSOME_II", "CHROMOSOME_III", "CHROMOSOME_IV", "CHROMOSOME_V","CHROMOSOME_X"] # "TES_q1" "strong_rex" "weak_rex" "type", "X", "Autosome"; Must be same number of unique values in selected bed rows.
chr_type_selected = ["X","Autosome"] # 'X' or "Autosome"
type_selected = ["200kb_region"] #TES_q1-4 | #TSS_q1-4 | strong/weak rex | whole_chr | 200kb_region | 50kb_region
max_regions = 0 # max regions to consider; 0 = full set;
chromosome_selected = ["CHROMOSOME_I", "CHROMOSOME_II", "CHROMOSOME_III", "CHROMOSOME_IV", "CHROMOSOME_V","CHROMOSOME_X"]
strand_selected = ["+","-"] #+ and/or -
bed_file = "~/Data1/reference/tss_tes_rex_combined.bed"
mods = "A" # {A,CG,A+CG}
if sample_source == "chr_type":
    selection = chr_type_selected
if sample_source == "type":
    selection = type_selected
if sample_source == "chromosome":
    selection = chromosome_selected

## Bam file configurations
random.seed(10)

### Tube D
#bam_frac = 1 # For full .bam set to = 1
#bam_file = "/Data1/seq_data/TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22/basecalls/m6A/mod_mappings.sorted.bam"
#output_stem = "/Data1/seq_data/TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22/basecalls/m6A/"
#condition = "N2; 2uM Hia5 30min"

### Tube 4
#bam_frac = 1 # For full .bam set to = 1
#bam_file = "/Data1/seq_data/Tube4_b2_2uM-Hia5_fiber-seq_11_21_22/basecalls/mod_mappings.sorted.m6Aonly.bam"
#output_stem = "/Data1/seq_data/Tube4_b2_2uM-Hia5_fiber-seq_11_21_22/basecalls/"
#condition = "N2; 2uM Hia5 120min"

### Tube H
#bam_frac = 1 # For full .bam set to = 1
#bam_file = "/Data1/seq_data/TubeH1_021_SDC2-AIDpAux_Hia5_MSssI_12_19/basecalls/m6A/mod_mappings.sorted.bam"
#output_stem = "/Data1/seq_data/TubeH1_021_SDC2-AIDpAux_Hia5_MSssI_12_19/basecalls/m6A/"
#condition = "AID::SDC-2 + Auxin; 2uM Hia5 30min"

### Tube T
bam_frac = 1 # For full .bam set to = 1
bam_file = "/Data1/seq_data/TubeT_N2_Young_FiberSeq_02_14_23_v3/basecalls/m6A/mod_mappings.sorted.m6Aonly.bam"
output_stem = "/Data1/seq_data/TubeT_N2_Young_FiberSeq_02_14_23_v3/basecalls/m6A/"
condition = "N2 Young; 2uM Hia5 30min"

# %%
### Select bed file
full_bed = pd.read_csv(bed_file,sep='\t')
bed=[]

for each_type in selection:
# REGION CONFIGURATION
    if sample_source == "type":
        temp_bed = full_bed[full_bed["chromosome"].isin(chromosome_selected) &
                            full_bed["chr-type"].isin(chr_type_selected) &
                            full_bed["type"].str.contains(each_type) &
                            full_bed["strand"].isin(strand_selected)]
    if sample_source == "chr_type":
        temp_bed = full_bed[full_bed["chromosome"].isin(chromosome_selected) &
                            full_bed["chr-type"].str.contains(each_type) &
                            full_bed["type"].isin(type_selected) &
                            full_bed["strand"].isin(strand_selected)]
    if sample_source == "chromosome":
        temp_bed = full_bed[full_bed["chromosome"].str.contains(each_type) &
                            full_bed["chr-type"].isin(chr_type_selected) &
                            full_bed["type"].isin(type_selected) &
                            full_bed["strand"].isin(strand_selected)]

    # Drop random regions to match max_regions
    drop_count = len(temp_bed)-max_regions
    # If max regions > selected regions, do not drop any.
    if(drop_count<0):
        drop_count=0
    # If max_regions = 0, do not drop any.
    if (max_regions == 0):
        drop_count = 0

    drop_indices = np.random.choice(temp_bed.index, drop_count, replace=False)
    temp_bed.drop(drop_indices,inplace=True)
    temp_bed.sort_values(by=["chromosome","start"],ascending=True,inplace=True)
    temp_bed.reset_index(drop=True, inplace=True)
    temp_bed["start"]=temp_bed["start"]
    temp_bed["end"]=temp_bed["end"]
    temp_bedfile = "/Data1/reference/temp_do_not_use_"+each_type+".bed"
    temp_bedfile_gz = "/Data1/reference/temp_do_not_use_"+each_type+".bed.gz"
    temp_bed.to_csv(temp_bedfile, sep="\t",header=False,index=False)
    
    # Create indexed tabix files
    ! bgzip -c {temp_bedfile} > {temp_bedfile_gz}
    ! tabix -f -p bed {temp_bedfile_gz}

    # For first iteration
    if bed == []:
        bed = [temp_bedfile]

    # Otherwise append region to temporary bed file.
    else:
        bed.append(temp_bedfile)
# Out:
# /tmp/ipykernel_6222/1142934343.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_bed.drop(drop_indices,inplace=True)
# /tmp/ipykernel_6222/1142934343.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_bed.sort_values(by=["chromosome","start"],ascending=True,inplace=True)
# /tmp/ipykernel_6222/1142934343.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_bed["start"]=temp_bed["start"]
# /tmp/ipykernel_6222/1142934343.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_bed["end"]=temp_bed["end"]

# %%
### Extract only reads in bam file that overlap selected regions, and subselect down using fraction
# Define function to generate redux .bam file
def extract_overlapping_reads(bed_file, bam_file, output_file):
    # Load the BAM file
    bam_ext = pysam.AlignmentFile(bam_file, "rb")

    # Load the BED file
    regions = pysam.TabixFile(bed_file)

    '''# Create the output BAM file
    out_bam = pysam.AlignmentFile(output_file, "wb", template=bam)

    # Iterate over the reads in the input BAM file
    for read in bam:
        # Check if the read overlaps a region in the BED file
        overlaps = [r for r in regions.fetch(read.reference_name, read.reference_start, read.reference_end)]
        if len(overlaps) > 0:
            # Write the read to the output BAM file if it overlaps a region in the BED file
            out_bam.write(read)

    # Close the input BAM file and the output BAM file
    bam.close()
    out_bam.close()'''

    # Create a set to store the reads
    seen = set()

    # Create the output .bam file
    with pysam.AlignmentFile(output_file, "wb", header=bam_ext.header) as out:
        # Iterate over the regions in the .bed file
        for region in regions.fetch():
            print(region)
            chrom, start, end, strand, region_type, chr_type = region.split()
            start, end = int(start), int(end)

            # Iterate over the reads in the current region
            for pileupcolumn in bam_ext.pileup(chrom, start, end):
                for pileupread in pileupcolumn.pileups:
                    # Check if the read has not been seen before
                    if pileupread.alignment.query_name not in seen:
                        # Add the read to the set of seen reads
                        seen.add(pileupread.alignment.query_name)
                        # Write the read to the output .bam file
                        out.write(pileupread.alignment)
    
for each_type in selection:
    temp_bedfile = "/Data1/reference/temp_do_not_use_"+each_type+".bed.gz"
    output_bamfile = output_stem + "mod_mappings_" + str(bam_frac)+"_"+each_type+".sorted.bam"
    extract_overlapping_reads(temp_bedfile, bam_file, output_bamfile)
    ### Subselect bam file using fraction
    ! samtools view -h -s {bam_frac} -L {temp_bedfile} {bam_file} | samtools view -h -b - > {output_bamfile}
    ! samtools index {output_bamfile}
# Out:
# CHROMOSOME_I	0	199999	+	200kb_region	Autosome
# CHROMOSOME_I	200000	399999	+	200kb_region	Autosome
# CHROMOSOME_I	400000	599999	+	200kb_region	Autosome
# CHROMOSOME_I	600000	799999	+	200kb_region	Autosome
# CHROMOSOME_I	800000	999999	+	200kb_region	Autosome
# CHROMOSOME_I	1000000	1199999	+	200kb_region	Autosome
# CHROMOSOME_I	1200000	1399999	+	200kb_region	Autosome
# CHROMOSOME_I	1400000	1599999	+	200kb_region	Autosome
# CHROMOSOME_I	1600000	1799999	+	200kb_region	Autosome
# CHROMOSOME_I	1800000	1999999	+	200kb_region	Autosome
# CHROMOSOME_I	2000000	2199999	+	200kb_region	Autosome
# CHROMOSOME_I	2200000	2399999	+	200kb_region	Autosome
# CHROMOSOME_I	2400000	2599999	+	200kb_region	Autosome
# CHROMOSOME_I	2600000	2799999	+	200kb_region	Autosome
# CHROMOSOME_I	2800000	2999999	+	200kb_region	Autosome
# CHROMOSOME_I	3000000	3199999	+	200kb_region	Autosome
# CHROMOSOME_I	3200000	3399999	+	200kb_region	Autosome
# CHROMOSOME_I	3400000	3599999	+	200kb_region	Autosome
# CHROMOSOME_I	3600000	3799999	+	200kb_region	Autosome
# CHROMOSOME_I	3800000	3999999	+	200kb_region	Autosome
# CHROMOSOME_I	4000000	4199999	+	200kb_region	Autosome
# CHROMOSOME_I	4200000	4399999	+	200kb_region	Autosome
# CHROMOSOME_I	4400000	4599999	+	200kb_region	Autosome
# CHROMOSOME_I	4600000	4799999	+	200kb_region	Autosome
# CHROMOSOME_I	4800000	4999999	+	200kb_region	Autosome
# CHROMOSOME_I	5000000	5199999	+	200kb_region	Autosome
# CHROMOSOME_I	5200000	5399999	+	200kb_region	Autosome
# CHROMOSOME_I	5400000	5599999	+	200kb_region	Autosome
# CHROMOSOME_I	5600000	5799999	+	200kb_region	Autosome
# CHROMOSOME_I	5800000	5999999	+	200kb_region	Autosome
# CHROMOSOME_I	6000000	6199999	+	200kb_region	Autosome
# CHROMOSOME_I	6200000	6399999	+	200kb_region	Autosome
# CHROMOSOME_I	6400000	6599999	+	200kb_region	Autosome
# CHROMOSOME_I	6600000	6799999	+	200kb_region	Autosome
# CHROMOSOME_I	6800000	6999999	+	200kb_region	Autosome
# CHROMOSOME_I	7000000	7199999	+	200kb_region	Autosome
# CHROMOSOME_I	7200000	7399999	+	200kb_region	Autosome
# CHROMOSOME_I	7400000	7599999	+	200kb_region	Autosome
# CHROMOSOME_I	7600000	7799999	+	200kb_region	Autosome
# CHROMOSOME_I	7800000	7999999	+	200kb_region	Autosome
# CHROMOSOME_I	8000000	8199999	+	200kb_region	Autosome
# CHROMOSOME_I	8200000	8399999	+	200kb_region	Autosome
# CHROMOSOME_I	8400000	8599999	+	200kb_region	Autosome
# CHROMOSOME_I	8600000	8799999	+	200kb_region	Autosome
# CHROMOSOME_I	8800000	8999999	+	200kb_region	Autosome
# CHROMOSOME_I	9000000	9199999	+	200kb_region	Autosome
# CHROMOSOME_I	9200000	9399999	+	200kb_region	Autosome
# CHROMOSOME_I	9400000	9599999	+	200kb_region	Autosome
# CHROMOSOME_I	9600000	9799999	+	200kb_region	Autosome
# CHROMOSOME_I	9800000	9999999	+	200kb_region	Autosome
# CHROMOSOME_I	10000000	10199999	+	200kb_region	Autosome
# CHROMOSOME_I	10200000	10399999	+	200kb_region	Autosome
# CHROMOSOME_I	10400000	10599999	+	200kb_region	Autosome
# CHROMOSOME_I	10600000	10799999	+	200kb_region	Autosome
# CHROMOSOME_I	10800000	10999999	+	200kb_region	Autosome
# CHROMOSOME_I	11000000	11199999	+	200kb_region	Autosome
# CHROMOSOME_I	11200000	11399999	+	200kb_region	Autosome
# CHROMOSOME_I	11400000	11599999	+	200kb_region	Autosome
# CHROMOSOME_I	11600000	11799999	+	200kb_region	Autosome
# CHROMOSOME_I	11800000	11999999	+	200kb_region	Autosome
# CHROMOSOME_I	12000000	12199999	+	200kb_region	Autosome
# CHROMOSOME_I	12200000	12399999	+	200kb_region	Autosome
# CHROMOSOME_I	12400000	12599999	+	200kb_region	Autosome
# CHROMOSOME_I	12600000	12799999	+	200kb_region	Autosome
# CHROMOSOME_I	12800000	12999999	+	200kb_region	Autosome
# CHROMOSOME_I	13000000	13199999	+	200kb_region	Autosome
# CHROMOSOME_I	13200000	13399999	+	200kb_region	Autosome
# CHROMOSOME_I	13400000	13599999	+	200kb_region	Autosome
# CHROMOSOME_I	13600000	13799999	+	200kb_region	Autosome
# CHROMOSOME_I	13800000	13999999	+	200kb_region	Autosome
# CHROMOSOME_I	14000000	14199999	+	200kb_region	Autosome
# CHROMOSOME_I	14200000	14399999	+	200kb_region	Autosome
# CHROMOSOME_I	14400000	14599999	+	200kb_region	Autosome
# CHROMOSOME_I	14600000	14799999	+	200kb_region	Autosome
# CHROMOSOME_I	14800000	14999999	+	200kb_region	Autosome
# CHROMOSOME_I	15000000	15072434	+	200kb_region	Autosome
# CHROMOSOME_II	0	199999	+	200kb_region	Autosome
# CHROMOSOME_II	200000	399999	+	200kb_region	Autosome
# CHROMOSOME_II	400000	599999	+	200kb_region	Autosome
# CHROMOSOME_II	600000	799999	+	200kb_region	Autosome
# CHROMOSOME_II	800000	999999	+	200kb_region	Autosome
# CHROMOSOME_II	1000000	1199999	+	200kb_region	Autosome
# CHROMOSOME_II	1200000	1399999	+	200kb_region	Autosome
# CHROMOSOME_II	1400000	1599999	+	200kb_region	Autosome
# CHROMOSOME_II	1600000	1799999	+	200kb_region	Autosome
# CHROMOSOME_II	1800000	1999999	+	200kb_region	Autosome
# CHROMOSOME_II	2000000	2199999	+	200kb_region	Autosome
# CHROMOSOME_II	2200000	2399999	+	200kb_region	Autosome
# CHROMOSOME_II	2400000	2599999	+	200kb_region	Autosome
# CHROMOSOME_II	2600000	2799999	+	200kb_region	Autosome
# CHROMOSOME_II	2800000	2999999	+	200kb_region	Autosome
# CHROMOSOME_II	3000000	3199999	+	200kb_region	Autosome
# CHROMOSOME_II	3200000	3399999	+	200kb_region	Autosome
# CHROMOSOME_II	3400000	3599999	+	200kb_region	Autosome
# CHROMOSOME_II	3600000	3799999	+	200kb_region	Autosome
# CHROMOSOME_II	3800000	3999999	+	200kb_region	Autosome
# CHROMOSOME_II	4000000	4199999	+	200kb_region	Autosome
# CHROMOSOME_II	4200000	4399999	+	200kb_region	Autosome
# CHROMOSOME_II	4400000	4599999	+	200kb_region	Autosome
# CHROMOSOME_II	4600000	4799999	+	200kb_region	Autosome
# CHROMOSOME_II	4800000	4999999	+	200kb_region	Autosome
# CHROMOSOME_II	5000000	5199999	+	200kb_region	Autosome
# CHROMOSOME_II	5200000	5399999	+	200kb_region	Autosome
# CHROMOSOME_II	5400000	5599999	+	200kb_region	Autosome
# CHROMOSOME_II	5600000	5799999	+	200kb_region	Autosome
# CHROMOSOME_II	5800000	5999999	+	200kb_region	Autosome
# CHROMOSOME_II	6000000	6199999	+	200kb_region	Autosome
# CHROMOSOME_II	6200000	6399999	+	200kb_region	Autosome
# CHROMOSOME_II	6400000	6599999	+	200kb_region	Autosome
# CHROMOSOME_II	6600000	6799999	+	200kb_region	Autosome
# CHROMOSOME_II	6800000	6999999	+	200kb_region	Autosome
# CHROMOSOME_II	7000000	7199999	+	200kb_region	Autosome
# CHROMOSOME_II	7200000	7399999	+	200kb_region	Autosome
# CHROMOSOME_II	7400000	7599999	+	200kb_region	Autosome
# CHROMOSOME_II	7600000	7799999	+	200kb_region	Autosome
# CHROMOSOME_II	7800000	7999999	+	200kb_region	Autosome
# CHROMOSOME_II	8000000	8199999	+	200kb_region	Autosome
# CHROMOSOME_II	8200000	8399999	+	200kb_region	Autosome
# CHROMOSOME_II	8400000	8599999	+	200kb_region	Autosome
# CHROMOSOME_II	8600000	8799999	+	200kb_region	Autosome
# CHROMOSOME_II	8800000	8999999	+	200kb_region	Autosome
# CHROMOSOME_II	9000000	9199999	+	200kb_region	Autosome
# CHROMOSOME_II	9200000	9399999	+	200kb_region	Autosome
# CHROMOSOME_II	9400000	9599999	+	200kb_region	Autosome
# CHROMOSOME_II	9600000	9799999	+	200kb_region	Autosome
# CHROMOSOME_II	9800000	9999999	+	200kb_region	Autosome
# CHROMOSOME_II	10000000	10199999	+	200kb_region	Autosome
# CHROMOSOME_II	10200000	10399999	+	200kb_region	Autosome
# CHROMOSOME_II	10400000	10599999	+	200kb_region	Autosome
# CHROMOSOME_II	10600000	10799999	+	200kb_region	Autosome
# CHROMOSOME_II	10800000	10999999	+	200kb_region	Autosome
# CHROMOSOME_II	11000000	11199999	+	200kb_region	Autosome
# CHROMOSOME_II	11200000	11399999	+	200kb_region	Autosome
# CHROMOSOME_II	11400000	11599999	+	200kb_region	Autosome
# CHROMOSOME_II	11600000	11799999	+	200kb_region	Autosome
# CHROMOSOME_II	11800000	11999999	+	200kb_region	Autosome
# CHROMOSOME_II	12000000	12199999	+	200kb_region	Autosome
# CHROMOSOME_II	12200000	12399999	+	200kb_region	Autosome
# CHROMOSOME_II	12400000	12599999	+	200kb_region	Autosome
# CHROMOSOME_II	12600000	12799999	+	200kb_region	Autosome
# CHROMOSOME_II	12800000	12999999	+	200kb_region	Autosome
# CHROMOSOME_II	13000000	13199999	+	200kb_region	Autosome
# CHROMOSOME_II	13200000	13399999	+	200kb_region	Autosome
# CHROMOSOME_II	13400000	13599999	+	200kb_region	Autosome
# CHROMOSOME_II	13600000	13799999	+	200kb_region	Autosome
# CHROMOSOME_II	13800000	13999999	+	200kb_region	Autosome
# CHROMOSOME_II	14000000	14199999	+	200kb_region	Autosome
# CHROMOSOME_II	14200000	14399999	+	200kb_region	Autosome
# CHROMOSOME_II	14400000	14599999	+	200kb_region	Autosome
# CHROMOSOME_II	14600000	14799999	+	200kb_region	Autosome
# CHROMOSOME_II	14800000	14999999	+	200kb_region	Autosome
# CHROMOSOME_II	15000000	15199999	+	200kb_region	Autosome
# CHROMOSOME_II	15200000	15279421	+	200kb_region	Autosome
# CHROMOSOME_III	0	199999	+	200kb_region	Autosome
# CHROMOSOME_III	200000	399999	+	200kb_region	Autosome
# CHROMOSOME_III	400000	599999	+	200kb_region	Autosome
# CHROMOSOME_III	600000	799999	+	200kb_region	Autosome
# CHROMOSOME_III	800000	999999	+	200kb_region	Autosome
# CHROMOSOME_III	1000000	1199999	+	200kb_region	Autosome
# CHROMOSOME_III	1200000	1399999	+	200kb_region	Autosome
# CHROMOSOME_III	1400000	1599999	+	200kb_region	Autosome
# CHROMOSOME_III	1600000	1799999	+	200kb_region	Autosome
# CHROMOSOME_III	1800000	1999999	+	200kb_region	Autosome
# CHROMOSOME_III	2000000	2199999	+	200kb_region	Autosome
# CHROMOSOME_III	2200000	2399999	+	200kb_region	Autosome
# CHROMOSOME_III	2400000	2599999	+	200kb_region	Autosome
# CHROMOSOME_III	2600000	2799999	+	200kb_region	Autosome
# CHROMOSOME_III	2800000	2999999	+	200kb_region	Autosome
# CHROMOSOME_III	3000000	3199999	+	200kb_region	Autosome
# CHROMOSOME_III	3200000	3399999	+	200kb_region	Autosome
# CHROMOSOME_III	3400000	3599999	+	200kb_region	Autosome
# CHROMOSOME_III	3600000	3799999	+	200kb_region	Autosome
# CHROMOSOME_III	3800000	3999999	+	200kb_region	Autosome
# CHROMOSOME_III	4000000	4199999	+	200kb_region	Autosome
# CHROMOSOME_III	4200000	4399999	+	200kb_region	Autosome
# CHROMOSOME_III	4400000	4599999	+	200kb_region	Autosome
# CHROMOSOME_III	4600000	4799999	+	200kb_region	Autosome
# CHROMOSOME_III	4800000	4999999	+	200kb_region	Autosome
# CHROMOSOME_III	5000000	5199999	+	200kb_region	Autosome
# CHROMOSOME_III	5200000	5399999	+	200kb_region	Autosome
# CHROMOSOME_III	5400000	5599999	+	200kb_region	Autosome
# CHROMOSOME_III	5600000	5799999	+	200kb_region	Autosome
# CHROMOSOME_III	5800000	5999999	+	200kb_region	Autosome
# CHROMOSOME_III	6000000	6199999	+	200kb_region	Autosome
# CHROMOSOME_III	6200000	6399999	+	200kb_region	Autosome
# CHROMOSOME_III	6400000	6599999	+	200kb_region	Autosome
# CHROMOSOME_III	6600000	6799999	+	200kb_region	Autosome
# CHROMOSOME_III	6800000	6999999	+	200kb_region	Autosome
# CHROMOSOME_III	7000000	7199999	+	200kb_region	Autosome
# CHROMOSOME_III	7200000	7399999	+	200kb_region	Autosome
# CHROMOSOME_III	7400000	7599999	+	200kb_region	Autosome
# CHROMOSOME_III	7600000	7799999	+	200kb_region	Autosome
# CHROMOSOME_III	7800000	7999999	+	200kb_region	Autosome
# CHROMOSOME_III	8000000	8199999	+	200kb_region	Autosome
# CHROMOSOME_III	8200000	8399999	+	200kb_region	Autosome
# CHROMOSOME_III	8400000	8599999	+	200kb_region	Autosome
# CHROMOSOME_III	8600000	8799999	+	200kb_region	Autosome
# CHROMOSOME_III	8800000	8999999	+	200kb_region	Autosome
# CHROMOSOME_III	9000000	9199999	+	200kb_region	Autosome
# CHROMOSOME_III	9200000	9399999	+	200kb_region	Autosome
# CHROMOSOME_III	9400000	9599999	+	200kb_region	Autosome
# CHROMOSOME_III	9600000	9799999	+	200kb_region	Autosome
# CHROMOSOME_III	9800000	9999999	+	200kb_region	Autosome
# CHROMOSOME_III	10000000	10199999	+	200kb_region	Autosome
# CHROMOSOME_III	10200000	10399999	+	200kb_region	Autosome
# CHROMOSOME_III	10400000	10599999	+	200kb_region	Autosome
# CHROMOSOME_III	10600000	10799999	+	200kb_region	Autosome
# CHROMOSOME_III	10800000	10999999	+	200kb_region	Autosome
# CHROMOSOME_III	11000000	11199999	+	200kb_region	Autosome
# CHROMOSOME_III	11200000	11399999	+	200kb_region	Autosome
# CHROMOSOME_III	11400000	11599999	+	200kb_region	Autosome
# CHROMOSOME_III	11600000	11799999	+	200kb_region	Autosome
# CHROMOSOME_III	11800000	11999999	+	200kb_region	Autosome
# CHROMOSOME_III	12000000	12199999	+	200kb_region	Autosome
# CHROMOSOME_III	12200000	12399999	+	200kb_region	Autosome
# CHROMOSOME_III	12400000	12599999	+	200kb_region	Autosome
# CHROMOSOME_III	12600000	12799999	+	200kb_region	Autosome
# CHROMOSOME_III	12800000	12999999	+	200kb_region	Autosome
# CHROMOSOME_III	13000000	13199999	+	200kb_region	Autosome
# CHROMOSOME_III	13200000	13399999	+	200kb_region	Autosome
# CHROMOSOME_III	13400000	13599999	+	200kb_region	Autosome
# CHROMOSOME_III	13600000	13783801	+	200kb_region	Autosome
# CHROMOSOME_IV	0	199999	+	200kb_region	Autosome
# CHROMOSOME_IV	200000	399999	+	200kb_region	Autosome
# CHROMOSOME_IV	400000	599999	+	200kb_region	Autosome
# CHROMOSOME_IV	600000	799999	+	200kb_region	Autosome
# CHROMOSOME_IV	800000	999999	+	200kb_region	Autosome
# CHROMOSOME_IV	1000000	1199999	+	200kb_region	Autosome
# CHROMOSOME_IV	1200000	1399999	+	200kb_region	Autosome
# CHROMOSOME_IV	1400000	1599999	+	200kb_region	Autosome
# CHROMOSOME_IV	1600000	1799999	+	200kb_region	Autosome
# CHROMOSOME_IV	1800000	1999999	+	200kb_region	Autosome
# CHROMOSOME_IV	2000000	2199999	+	200kb_region	Autosome
# CHROMOSOME_IV	2200000	2399999	+	200kb_region	Autosome
# CHROMOSOME_IV	2400000	2599999	+	200kb_region	Autosome
# CHROMOSOME_IV	2600000	2799999	+	200kb_region	Autosome
# CHROMOSOME_IV	2800000	2999999	+	200kb_region	Autosome
# CHROMOSOME_IV	3000000	3199999	+	200kb_region	Autosome
# CHROMOSOME_IV	3200000	3399999	+	200kb_region	Autosome
# CHROMOSOME_IV	3400000	3599999	+	200kb_region	Autosome
# CHROMOSOME_IV	3600000	3799999	+	200kb_region	Autosome
# CHROMOSOME_IV	3800000	3999999	+	200kb_region	Autosome
# CHROMOSOME_IV	4000000	4199999	+	200kb_region	Autosome
# CHROMOSOME_IV	4200000	4399999	+	200kb_region	Autosome
# CHROMOSOME_IV	4400000	4599999	+	200kb_region	Autosome
# CHROMOSOME_IV	4600000	4799999	+	200kb_region	Autosome
# CHROMOSOME_IV	4800000	4999999	+	200kb_region	Autosome
# CHROMOSOME_IV	5000000	5199999	+	200kb_region	Autosome
# CHROMOSOME_IV	5200000	5399999	+	200kb_region	Autosome
# CHROMOSOME_IV	5400000	5599999	+	200kb_region	Autosome
# CHROMOSOME_IV	5600000	5799999	+	200kb_region	Autosome
# CHROMOSOME_IV	5800000	5999999	+	200kb_region	Autosome
# CHROMOSOME_IV	6000000	6199999	+	200kb_region	Autosome
# CHROMOSOME_IV	6200000	6399999	+	200kb_region	Autosome
# CHROMOSOME_IV	6400000	6599999	+	200kb_region	Autosome
# CHROMOSOME_IV	6600000	6799999	+	200kb_region	Autosome
# CHROMOSOME_IV	6800000	6999999	+	200kb_region	Autosome
# CHROMOSOME_IV	7000000	7199999	+	200kb_region	Autosome
# CHROMOSOME_IV	7200000	7399999	+	200kb_region	Autosome
# CHROMOSOME_IV	7400000	7599999	+	200kb_region	Autosome
# CHROMOSOME_IV	7600000	7799999	+	200kb_region	Autosome
# CHROMOSOME_IV	7800000	7999999	+	200kb_region	Autosome
# CHROMOSOME_IV	8000000	8199999	+	200kb_region	Autosome
# CHROMOSOME_IV	8200000	8399999	+	200kb_region	Autosome
# CHROMOSOME_IV	8400000	8599999	+	200kb_region	Autosome
# CHROMOSOME_IV	8600000	8799999	+	200kb_region	Autosome
# CHROMOSOME_IV	8800000	8999999	+	200kb_region	Autosome
# CHROMOSOME_IV	9000000	9199999	+	200kb_region	Autosome
# CHROMOSOME_IV	9200000	9399999	+	200kb_region	Autosome
# CHROMOSOME_IV	9400000	9599999	+	200kb_region	Autosome
# CHROMOSOME_IV	9600000	9799999	+	200kb_region	Autosome
# CHROMOSOME_IV	9800000	9999999	+	200kb_region	Autosome
# CHROMOSOME_IV	10000000	10199999	+	200kb_region	Autosome
# CHROMOSOME_IV	10200000	10399999	+	200kb_region	Autosome
# CHROMOSOME_IV	10400000	10599999	+	200kb_region	Autosome
# CHROMOSOME_IV	10600000	10799999	+	200kb_region	Autosome
# CHROMOSOME_IV	10800000	10999999	+	200kb_region	Autosome
# CHROMOSOME_IV	11000000	11199999	+	200kb_region	Autosome
# CHROMOSOME_IV	11200000	11399999	+	200kb_region	Autosome
# CHROMOSOME_IV	11400000	11599999	+	200kb_region	Autosome
# CHROMOSOME_IV	11600000	11799999	+	200kb_region	Autosome
# CHROMOSOME_IV	11800000	11999999	+	200kb_region	Autosome
# CHROMOSOME_IV	12000000	12199999	+	200kb_region	Autosome
# CHROMOSOME_IV	12200000	12399999	+	200kb_region	Autosome
# CHROMOSOME_IV	12400000	12599999	+	200kb_region	Autosome
# CHROMOSOME_IV	12600000	12799999	+	200kb_region	Autosome
# CHROMOSOME_IV	12800000	12999999	+	200kb_region	Autosome
# CHROMOSOME_IV	13000000	13199999	+	200kb_region	Autosome
# CHROMOSOME_IV	13200000	13399999	+	200kb_region	Autosome
# CHROMOSOME_IV	13400000	13599999	+	200kb_region	Autosome
# CHROMOSOME_IV	13600000	13799999	+	200kb_region	Autosome
# CHROMOSOME_IV	13800000	13999999	+	200kb_region	Autosome
# CHROMOSOME_IV	14000000	14199999	+	200kb_region	Autosome
# CHROMOSOME_IV	14200000	14399999	+	200kb_region	Autosome
# CHROMOSOME_IV	14400000	14599999	+	200kb_region	Autosome
# CHROMOSOME_IV	14600000	14799999	+	200kb_region	Autosome
# CHROMOSOME_IV	14800000	14999999	+	200kb_region	Autosome
# CHROMOSOME_IV	15000000	15199999	+	200kb_region	Autosome
# CHROMOSOME_IV	15200000	15399999	+	200kb_region	Autosome
# CHROMOSOME_IV	15400000	15599999	+	200kb_region	Autosome
# CHROMOSOME_IV	15600000	15799999	+	200kb_region	Autosome
# CHROMOSOME_IV	15800000	15999999	+	200kb_region	Autosome
# CHROMOSOME_IV	16000000	16199999	+	200kb_region	Autosome
# CHROMOSOME_IV	16200000	16399999	+	200kb_region	Autosome
# CHROMOSOME_IV	16400000	16599999	+	200kb_region	Autosome
# CHROMOSOME_IV	16600000	16799999	+	200kb_region	Autosome
# CHROMOSOME_IV	16800000	16999999	+	200kb_region	Autosome
# CHROMOSOME_IV	17000000	17199999	+	200kb_region	Autosome
# CHROMOSOME_IV	17200000	17399999	+	200kb_region	Autosome
# CHROMOSOME_IV	17400000	17493829	+	200kb_region	Autosome
# CHROMOSOME_V	0	199999	+	200kb_region	Autosome
# CHROMOSOME_V	200000	399999	+	200kb_region	Autosome
# CHROMOSOME_V	400000	599999	+	200kb_region	Autosome
# CHROMOSOME_V	600000	799999	+	200kb_region	Autosome
# CHROMOSOME_V	800000	999999	+	200kb_region	Autosome
# CHROMOSOME_V	1000000	1199999	+	200kb_region	Autosome
# CHROMOSOME_V	1200000	1399999	+	200kb_region	Autosome
# CHROMOSOME_V	1400000	1599999	+	200kb_region	Autosome
# CHROMOSOME_V	1600000	1799999	+	200kb_region	Autosome
# CHROMOSOME_V	1800000	1999999	+	200kb_region	Autosome
# CHROMOSOME_V	2000000	2199999	+	200kb_region	Autosome
# CHROMOSOME_V	2200000	2399999	+	200kb_region	Autosome
# CHROMOSOME_V	2400000	2599999	+	200kb_region	Autosome
# CHROMOSOME_V	2600000	2799999	+	200kb_region	Autosome
# CHROMOSOME_V	2800000	2999999	+	200kb_region	Autosome
# CHROMOSOME_V	3000000	3199999	+	200kb_region	Autosome
# CHROMOSOME_V	3200000	3399999	+	200kb_region	Autosome
# CHROMOSOME_V	3400000	3599999	+	200kb_region	Autosome
# CHROMOSOME_V	3600000	3799999	+	200kb_region	Autosome
# CHROMOSOME_V	3800000	3999999	+	200kb_region	Autosome
# CHROMOSOME_V	4000000	4199999	+	200kb_region	Autosome
# CHROMOSOME_V	4200000	4399999	+	200kb_region	Autosome
# CHROMOSOME_V	4400000	4599999	+	200kb_region	Autosome
# CHROMOSOME_V	4600000	4799999	+	200kb_region	Autosome
# CHROMOSOME_V	4800000	4999999	+	200kb_region	Autosome
# CHROMOSOME_V	5000000	5199999	+	200kb_region	Autosome
# CHROMOSOME_V	5200000	5399999	+	200kb_region	Autosome
# CHROMOSOME_V	5400000	5599999	+	200kb_region	Autosome
# CHROMOSOME_V	5600000	5799999	+	200kb_region	Autosome
# CHROMOSOME_V	5800000	5999999	+	200kb_region	Autosome
# CHROMOSOME_V	6000000	6199999	+	200kb_region	Autosome
# CHROMOSOME_V	6200000	6399999	+	200kb_region	Autosome
# CHROMOSOME_V	6400000	6599999	+	200kb_region	Autosome
# CHROMOSOME_V	6600000	6799999	+	200kb_region	Autosome
# CHROMOSOME_V	6800000	6999999	+	200kb_region	Autosome
# CHROMOSOME_V	7000000	7199999	+	200kb_region	Autosome
# CHROMOSOME_V	7200000	7399999	+	200kb_region	Autosome
# CHROMOSOME_V	7400000	7599999	+	200kb_region	Autosome
# CHROMOSOME_V	7600000	7799999	+	200kb_region	Autosome
# CHROMOSOME_V	7800000	7999999	+	200kb_region	Autosome
# CHROMOSOME_V	8000000	8199999	+	200kb_region	Autosome
# CHROMOSOME_V	8200000	8399999	+	200kb_region	Autosome
# CHROMOSOME_V	8400000	8599999	+	200kb_region	Autosome
# CHROMOSOME_V	8600000	8799999	+	200kb_region	Autosome
# CHROMOSOME_V	8800000	8999999	+	200kb_region	Autosome
# CHROMOSOME_V	9000000	9199999	+	200kb_region	Autosome
# CHROMOSOME_V	9200000	9399999	+	200kb_region	Autosome
# CHROMOSOME_V	9400000	9599999	+	200kb_region	Autosome
# CHROMOSOME_V	9600000	9799999	+	200kb_region	Autosome
# CHROMOSOME_V	9800000	9999999	+	200kb_region	Autosome
# CHROMOSOME_V	10000000	10199999	+	200kb_region	Autosome
# CHROMOSOME_V	10200000	10399999	+	200kb_region	Autosome
# CHROMOSOME_V	10400000	10599999	+	200kb_region	Autosome
# CHROMOSOME_V	10600000	10799999	+	200kb_region	Autosome
# CHROMOSOME_V	10800000	10999999	+	200kb_region	Autosome
# CHROMOSOME_V	11000000	11199999	+	200kb_region	Autosome
# CHROMOSOME_V	11200000	11399999	+	200kb_region	Autosome
# CHROMOSOME_V	11400000	11599999	+	200kb_region	Autosome
# CHROMOSOME_V	11600000	11799999	+	200kb_region	Autosome
# CHROMOSOME_V	11800000	11999999	+	200kb_region	Autosome
# CHROMOSOME_V	12000000	12199999	+	200kb_region	Autosome
# CHROMOSOME_V	12200000	12399999	+	200kb_region	Autosome
# CHROMOSOME_V	12400000	12599999	+	200kb_region	Autosome
# CHROMOSOME_V	12600000	12799999	+	200kb_region	Autosome
# CHROMOSOME_V	12800000	12999999	+	200kb_region	Autosome
# CHROMOSOME_V	13000000	13199999	+	200kb_region	Autosome
# CHROMOSOME_V	13200000	13399999	+	200kb_region	Autosome
# CHROMOSOME_V	13400000	13599999	+	200kb_region	Autosome
# CHROMOSOME_V	13600000	13799999	+	200kb_region	Autosome
# CHROMOSOME_V	13800000	13999999	+	200kb_region	Autosome
# CHROMOSOME_V	14000000	14199999	+	200kb_region	Autosome
# CHROMOSOME_V	14200000	14399999	+	200kb_region	Autosome
# CHROMOSOME_V	14400000	14599999	+	200kb_region	Autosome
# CHROMOSOME_V	14600000	14799999	+	200kb_region	Autosome
# CHROMOSOME_V	14800000	14999999	+	200kb_region	Autosome
# CHROMOSOME_V	15000000	15199999	+	200kb_region	Autosome
# CHROMOSOME_V	15200000	15399999	+	200kb_region	Autosome
# CHROMOSOME_V	15400000	15599999	+	200kb_region	Autosome
# CHROMOSOME_V	15600000	15799999	+	200kb_region	Autosome
# CHROMOSOME_V	15800000	15999999	+	200kb_region	Autosome
# CHROMOSOME_V	16000000	16199999	+	200kb_region	Autosome
# CHROMOSOME_V	16200000	16399999	+	200kb_region	Autosome
# CHROMOSOME_V	16400000	16599999	+	200kb_region	Autosome
# CHROMOSOME_V	16600000	16799999	+	200kb_region	Autosome
# CHROMOSOME_V	16800000	16999999	+	200kb_region	Autosome
# CHROMOSOME_V	17000000	17199999	+	200kb_region	Autosome
# CHROMOSOME_V	17200000	17399999	+	200kb_region	Autosome
# CHROMOSOME_V	17400000	17599999	+	200kb_region	Autosome
# CHROMOSOME_V	17600000	17799999	+	200kb_region	Autosome
# CHROMOSOME_V	17800000	17999999	+	200kb_region	Autosome
# CHROMOSOME_V	18000000	18199999	+	200kb_region	Autosome
# CHROMOSOME_V	18200000	18399999	+	200kb_region	Autosome
# CHROMOSOME_V	18400000	18599999	+	200kb_region	Autosome
# CHROMOSOME_V	18600000	18799999	+	200kb_region	Autosome
# CHROMOSOME_V	18800000	18999999	+	200kb_region	Autosome
# CHROMOSOME_V	19000000	19199999	+	200kb_region	Autosome
# CHROMOSOME_V	19200000	19399999	+	200kb_region	Autosome
# CHROMOSOME_V	19400000	19599999	+	200kb_region	Autosome
# CHROMOSOME_V	19600000	19799999	+	200kb_region	Autosome
# CHROMOSOME_V	19800000	19999999	+	200kb_region	Autosome
# CHROMOSOME_V	20000000	20199999	+	200kb_region	Autosome
# CHROMOSOME_V	20200000	20399999	+	200kb_region	Autosome
# CHROMOSOME_V	20400000	20599999	+	200kb_region	Autosome
# CHROMOSOME_V	20600000	20799999	+	200kb_region	Autosome
# CHROMOSOME_V	20800000	20924180	+	200kb_region	Autosome
# CHROMOSOME_X	0	199999	+	200kb_region	X
# CHROMOSOME_X	200000	399999	+	200kb_region	X
# CHROMOSOME_X	400000	599999	+	200kb_region	X
# CHROMOSOME_X	600000	799999	+	200kb_region	X
# CHROMOSOME_X	800000	999999	+	200kb_region	X
# CHROMOSOME_X	1000000	1199999	+	200kb_region	X
# CHROMOSOME_X	1200000	1399999	+	200kb_region	X
# CHROMOSOME_X	1400000	1599999	+	200kb_region	X
# CHROMOSOME_X	1600000	1799999	+	200kb_region	X
# CHROMOSOME_X	1800000	1999999	+	200kb_region	X
# CHROMOSOME_X	2000000	2199999	+	200kb_region	X
# CHROMOSOME_X	2200000	2399999	+	200kb_region	X
# CHROMOSOME_X	2400000	2599999	+	200kb_region	X
# CHROMOSOME_X	2600000	2799999	+	200kb_region	X
# CHROMOSOME_X	2800000	2999999	+	200kb_region	X
# CHROMOSOME_X	3000000	3199999	+	200kb_region	X
# CHROMOSOME_X	3200000	3399999	+	200kb_region	X
# CHROMOSOME_X	3400000	3599999	+	200kb_region	X
# CHROMOSOME_X	3600000	3799999	+	200kb_region	X
# CHROMOSOME_X	3800000	3999999	+	200kb_region	X
# CHROMOSOME_X	4000000	4199999	+	200kb_region	X
# CHROMOSOME_X	4200000	4399999	+	200kb_region	X
# CHROMOSOME_X	4400000	4599999	+	200kb_region	X
# CHROMOSOME_X	4600000	4799999	+	200kb_region	X
# CHROMOSOME_X	4800000	4999999	+	200kb_region	X
# CHROMOSOME_X	5000000	5199999	+	200kb_region	X
# CHROMOSOME_X	5200000	5399999	+	200kb_region	X
# CHROMOSOME_X	5400000	5599999	+	200kb_region	X
# CHROMOSOME_X	5600000	5799999	+	200kb_region	X
# CHROMOSOME_X	5800000	5999999	+	200kb_region	X
# CHROMOSOME_X	6000000	6199999	+	200kb_region	X
# CHROMOSOME_X	6200000	6399999	+	200kb_region	X
# CHROMOSOME_X	6400000	6599999	+	200kb_region	X
# CHROMOSOME_X	6600000	6799999	+	200kb_region	X
# CHROMOSOME_X	6800000	6999999	+	200kb_region	X
# CHROMOSOME_X	7000000	7199999	+	200kb_region	X
# CHROMOSOME_X	7200000	7399999	+	200kb_region	X
# CHROMOSOME_X	7400000	7599999	+	200kb_region	X
# CHROMOSOME_X	7600000	7799999	+	200kb_region	X
# CHROMOSOME_X	7800000	7999999	+	200kb_region	X
# CHROMOSOME_X	8000000	8199999	+	200kb_region	X
# CHROMOSOME_X	8200000	8399999	+	200kb_region	X
# CHROMOSOME_X	8400000	8599999	+	200kb_region	X
# CHROMOSOME_X	8600000	8799999	+	200kb_region	X
# CHROMOSOME_X	8800000	8999999	+	200kb_region	X
# CHROMOSOME_X	9000000	9199999	+	200kb_region	X
# CHROMOSOME_X	9200000	9399999	+	200kb_region	X
# CHROMOSOME_X	9400000	9599999	+	200kb_region	X
# CHROMOSOME_X	9600000	9799999	+	200kb_region	X
# CHROMOSOME_X	9800000	9999999	+	200kb_region	X
# CHROMOSOME_X	10000000	10199999	+	200kb_region	X
# CHROMOSOME_X	10200000	10399999	+	200kb_region	X
# CHROMOSOME_X	10400000	10599999	+	200kb_region	X
# CHROMOSOME_X	10600000	10799999	+	200kb_region	X
# CHROMOSOME_X	10800000	10999999	+	200kb_region	X
# CHROMOSOME_X	11000000	11199999	+	200kb_region	X
# CHROMOSOME_X	11200000	11399999	+	200kb_region	X
# CHROMOSOME_X	11400000	11599999	+	200kb_region	X
# CHROMOSOME_X	11600000	11799999	+	200kb_region	X
# CHROMOSOME_X	11800000	11999999	+	200kb_region	X
# CHROMOSOME_X	12000000	12199999	+	200kb_region	X
# CHROMOSOME_X	12200000	12399999	+	200kb_region	X
# CHROMOSOME_X	12400000	12599999	+	200kb_region	X
# CHROMOSOME_X	12600000	12799999	+	200kb_region	X
# CHROMOSOME_X	12800000	12999999	+	200kb_region	X
# CHROMOSOME_X	13000000	13199999	+	200kb_region	X
# CHROMOSOME_X	13200000	13399999	+	200kb_region	X
# CHROMOSOME_X	13400000	13599999	+	200kb_region	X
# CHROMOSOME_X	13600000	13799999	+	200kb_region	X
# CHROMOSOME_X	13800000	13999999	+	200kb_region	X
# CHROMOSOME_X	14000000	14199999	+	200kb_region	X
# CHROMOSOME_X	14200000	14399999	+	200kb_region	X
# CHROMOSOME_X	14400000	14599999	+	200kb_region	X
# CHROMOSOME_X	14600000	14799999	+	200kb_region	X
# CHROMOSOME_X	14800000	14999999	+	200kb_region	X
# CHROMOSOME_X	15000000	15199999	+	200kb_region	X
# CHROMOSOME_X	15200000	15399999	+	200kb_region	X
# CHROMOSOME_X	15400000	15599999	+	200kb_region	X
# CHROMOSOME_X	15600000	15799999	+	200kb_region	X
# CHROMOSOME_X	15800000	15999999	+	200kb_region	X
# CHROMOSOME_X	16000000	16199999	+	200kb_region	X
# CHROMOSOME_X	16200000	16399999	+	200kb_region	X
# CHROMOSOME_X	16400000	16599999	+	200kb_region	X
# CHROMOSOME_X	16600000	16799999	+	200kb_region	X
# CHROMOSOME_X	16800000	16999999	+	200kb_region	X
# CHROMOSOME_X	17000000	17199999	+	200kb_region	X
# CHROMOSOME_X	17200000	17399999	+	200kb_region	X
# CHROMOSOME_X	17400000	17599999	+	200kb_region	X
# CHROMOSOME_X	17600000	17718942	+	200kb_region	X

# %%
### Caculate average m6A per region based on input bed and bam files
def extract_m6A_per_region(bam_file, bed_file, threshold):
    # Load the BAM file
    bam_ext = pysam.AlignmentFile(bam_file, "rb")

    # Load the BED file
    regions = pysam.TabixFile(bed_file)

    # Initialize a list to store the results
    results = []

    # Iterate over the regions in the BED file
    for region in regions.fetch():
        # Split the region string into the chromosome, start, and end positions
        print("Starting on region:",region)
        chromosome, start, end, strand, region_type, chr_type = region.split()
        start = int(start)
        end = int(end)

        # Initialize counters for the total number of bases and the total number of m6A
        total_bases = 0
        total_m6A = 0

        # Iterate over the reads that overlap the region
        for read in bam_ext.fetch(chromosome, start, end):
            #print("starting on read:", read)
            # Count the total number of "A" bases in the read that overlap the region
            total_bases = total_bases + read.query_sequence.count("A")
            
            if read.is_forward == True:
                try: m6A_dict_values = [x[1] for x  in read.modified_bases[('A', 0, 'Y')]]
                except: m6A_dict_values = [x[1] for x  in read.modified_bases[('A', 0, 'a')]]
            else:
                try: m6A_dict_values = [x[1] for x  in read.modified_bases[('A', 1, 'Y')]]
                except: m6A_dict_values = [x[1] for x  in read.modified_bases[('A', 1, 'a')]]
            
            total_m6A = sum(i > threshold for i in m6A_dict_values) + total_m6A

        # Add the region information to the results list
        results.append([chromosome, start, end, region_type, chr_type, total_bases, total_m6A])

    # Close the BAM file
    bam_ext.close()

    # Convert the results list to a pandas dataframe
    df = pd.DataFrame(results, columns=["chromosome", "start", "rnd", "region_type", "chr_type", "total_bases", "total_m6A"])
    df["m6A_frac"] = df["total_m6A"]/df["total_bases"]
    df["norm_m6A_frac"] = df["m6A_frac"]/(df.loc[df['chr_type'] == 'Autosome', 'm6A_frac'].mean())
    df["condition"]= condition
    return df

for each_type in selection:
    bam = output_stem + "mod_mappings_" + str(bam_frac)+"_"+each_type+".sorted.bam"
    temp_bedfile = "/Data1/reference/temp_do_not_use_"+each_type+".bed.gz"
    output_df = extract_m6A_per_region(bam,temp_bedfile,m6A_thresh)
    output_df.to_csv(output_stem + "m6A_frac" + str(bam_frac)+"_"+each_type+".csv", index=False, mode='w')
    print(output_df)
# Out:
# Starting on region: CHROMOSOME_I	0	199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	200000	399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	400000	599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	600000	799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	800000	999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	1000000	1199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	1200000	1399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	1400000	1599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	1600000	1799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	1800000	1999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	2000000	2199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	2200000	2399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	2400000	2599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	2600000	2799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	2800000	2999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	3000000	3199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	3200000	3399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	3400000	3599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	3600000	3799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	3800000	3999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	4000000	4199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	4200000	4399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	4400000	4599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	4600000	4799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	4800000	4999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	5000000	5199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	5200000	5399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	5400000	5599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	5600000	5799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	5800000	5999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	6000000	6199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	6200000	6399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	6400000	6599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	6600000	6799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	6800000	6999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	7000000	7199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	7200000	7399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	7400000	7599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	7600000	7799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	7800000	7999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	8000000	8199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	8200000	8399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	8400000	8599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	8600000	8799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	8800000	8999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	9000000	9199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	9200000	9399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	9400000	9599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	9600000	9799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	9800000	9999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	10000000	10199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	10200000	10399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	10400000	10599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	10600000	10799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	10800000	10999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	11000000	11199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	11200000	11399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	11400000	11599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	11600000	11799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	11800000	11999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	12000000	12199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	12200000	12399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	12400000	12599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	12600000	12799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	12800000	12999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	13000000	13199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	13200000	13399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	13400000	13599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	13600000	13799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	13800000	13999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	14000000	14199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	14200000	14399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	14400000	14599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	14600000	14799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	14800000	14999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_I	15000000	15072434	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	0	199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	200000	399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	400000	599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	600000	799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	800000	999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	1000000	1199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	1200000	1399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	1400000	1599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	1600000	1799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	1800000	1999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	2000000	2199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	2200000	2399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	2400000	2599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	2600000	2799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	2800000	2999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	3000000	3199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	3200000	3399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	3400000	3599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	3600000	3799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	3800000	3999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	4000000	4199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	4200000	4399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	4400000	4599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	4600000	4799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	4800000	4999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	5000000	5199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	5200000	5399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	5400000	5599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	5600000	5799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	5800000	5999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	6000000	6199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	6200000	6399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	6400000	6599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	6600000	6799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	6800000	6999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	7000000	7199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	7200000	7399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	7400000	7599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	7600000	7799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	7800000	7999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	8000000	8199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	8200000	8399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	8400000	8599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	8600000	8799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	8800000	8999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	9000000	9199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	9200000	9399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	9400000	9599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	9600000	9799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	9800000	9999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	10000000	10199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	10200000	10399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	10400000	10599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	10600000	10799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	10800000	10999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	11000000	11199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	11200000	11399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	11400000	11599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	11600000	11799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	11800000	11999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	12000000	12199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	12200000	12399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	12400000	12599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	12600000	12799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	12800000	12999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	13000000	13199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	13200000	13399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	13400000	13599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	13600000	13799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	13800000	13999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	14000000	14199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	14200000	14399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	14400000	14599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	14600000	14799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	14800000	14999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	15000000	15199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_II	15200000	15279421	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	0	199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	200000	399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	400000	599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	600000	799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	800000	999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	1000000	1199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	1200000	1399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	1400000	1599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	1600000	1799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	1800000	1999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	2000000	2199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	2200000	2399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	2400000	2599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	2600000	2799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	2800000	2999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	3000000	3199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	3200000	3399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	3400000	3599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	3600000	3799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	3800000	3999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	4000000	4199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	4200000	4399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	4400000	4599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	4600000	4799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	4800000	4999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	5000000	5199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	5200000	5399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	5400000	5599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	5600000	5799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	5800000	5999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	6000000	6199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	6200000	6399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	6400000	6599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	6600000	6799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	6800000	6999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	7000000	7199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	7200000	7399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	7400000	7599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	7600000	7799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	7800000	7999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	8000000	8199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	8200000	8399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	8400000	8599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	8600000	8799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	8800000	8999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	9000000	9199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	9200000	9399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	9400000	9599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	9600000	9799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	9800000	9999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	10000000	10199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	10200000	10399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	10400000	10599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	10600000	10799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	10800000	10999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	11000000	11199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	11200000	11399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	11400000	11599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	11600000	11799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	11800000	11999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	12000000	12199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	12200000	12399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	12400000	12599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	12600000	12799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	12800000	12999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	13000000	13199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	13200000	13399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	13400000	13599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_III	13600000	13783801	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	0	199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	200000	399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	400000	599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	600000	799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	800000	999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	1000000	1199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	1200000	1399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	1400000	1599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	1600000	1799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	1800000	1999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	2000000	2199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	2200000	2399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	2400000	2599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	2600000	2799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	2800000	2999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	3000000	3199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	3200000	3399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	3400000	3599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	3600000	3799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	3800000	3999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	4000000	4199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	4200000	4399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	4400000	4599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	4600000	4799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	4800000	4999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	5000000	5199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	5200000	5399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	5400000	5599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	5600000	5799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	5800000	5999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	6000000	6199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	6200000	6399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	6400000	6599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	6600000	6799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	6800000	6999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	7000000	7199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	7200000	7399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	7400000	7599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	7600000	7799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	7800000	7999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	8000000	8199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	8200000	8399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	8400000	8599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	8600000	8799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	8800000	8999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	9000000	9199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	9200000	9399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	9400000	9599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	9600000	9799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	9800000	9999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	10000000	10199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	10200000	10399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	10400000	10599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	10600000	10799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	10800000	10999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	11000000	11199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	11200000	11399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	11400000	11599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	11600000	11799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	11800000	11999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	12000000	12199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	12200000	12399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	12400000	12599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	12600000	12799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	12800000	12999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	13000000	13199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	13200000	13399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	13400000	13599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	13600000	13799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	13800000	13999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	14000000	14199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	14200000	14399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	14400000	14599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	14600000	14799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	14800000	14999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	15000000	15199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	15200000	15399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	15400000	15599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	15600000	15799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	15800000	15999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	16000000	16199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	16200000	16399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	16400000	16599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	16600000	16799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	16800000	16999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	17000000	17199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	17200000	17399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_IV	17400000	17493829	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	0	199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	200000	399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	400000	599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	600000	799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	800000	999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	1000000	1199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	1200000	1399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	1400000	1599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	1600000	1799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	1800000	1999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	2000000	2199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	2200000	2399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	2400000	2599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	2600000	2799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	2800000	2999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	3000000	3199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	3200000	3399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	3400000	3599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	3600000	3799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	3800000	3999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	4000000	4199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	4200000	4399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	4400000	4599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	4600000	4799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	4800000	4999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	5000000	5199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	5200000	5399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	5400000	5599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	5600000	5799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	5800000	5999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	6000000	6199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	6200000	6399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	6400000	6599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	6600000	6799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	6800000	6999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	7000000	7199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	7200000	7399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	7400000	7599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	7600000	7799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	7800000	7999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	8000000	8199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	8200000	8399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	8400000	8599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	8600000	8799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	8800000	8999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	9000000	9199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	9200000	9399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	9400000	9599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	9600000	9799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	9800000	9999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	10000000	10199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	10200000	10399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	10400000	10599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	10600000	10799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	10800000	10999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	11000000	11199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	11200000	11399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	11400000	11599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	11600000	11799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	11800000	11999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	12000000	12199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	12200000	12399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	12400000	12599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	12600000	12799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	12800000	12999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	13000000	13199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	13200000	13399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	13400000	13599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	13600000	13799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	13800000	13999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	14000000	14199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	14200000	14399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	14400000	14599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	14600000	14799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	14800000	14999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	15000000	15199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	15200000	15399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	15400000	15599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	15600000	15799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	15800000	15999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	16000000	16199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	16200000	16399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	16400000	16599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	16600000	16799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	16800000	16999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	17000000	17199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	17200000	17399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	17400000	17599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	17600000	17799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	17800000	17999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	18000000	18199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	18200000	18399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	18400000	18599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	18600000	18799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	18800000	18999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	19000000	19199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	19200000	19399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	19400000	19599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	19600000	19799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	19800000	19999999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	20000000	20199999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	20200000	20399999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	20400000	20599999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	20600000	20799999	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_V	20800000	20924180	+	200kb_region	Autosome
# Starting on region: CHROMOSOME_X	0	199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	200000	399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	400000	599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	600000	799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	800000	999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	1000000	1199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	1200000	1399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	1400000	1599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	1600000	1799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	1800000	1999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	2000000	2199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	2200000	2399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	2400000	2599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	2600000	2799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	2800000	2999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	3000000	3199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	3200000	3399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	3400000	3599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	3600000	3799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	3800000	3999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	4000000	4199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	4200000	4399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	4400000	4599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	4600000	4799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	4800000	4999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	5000000	5199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	5200000	5399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	5400000	5599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	5600000	5799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	5800000	5999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	6000000	6199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	6200000	6399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	6400000	6599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	6600000	6799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	6800000	6999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	7000000	7199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	7200000	7399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	7400000	7599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	7600000	7799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	7800000	7999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	8000000	8199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	8200000	8399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	8400000	8599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	8600000	8799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	8800000	8999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	9000000	9199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	9200000	9399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	9400000	9599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	9600000	9799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	9800000	9999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	10000000	10199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	10200000	10399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	10400000	10599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	10600000	10799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	10800000	10999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	11000000	11199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	11200000	11399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	11400000	11599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	11600000	11799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	11800000	11999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	12000000	12199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	12200000	12399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	12400000	12599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	12600000	12799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	12800000	12999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	13000000	13199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	13200000	13399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	13400000	13599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	13600000	13799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	13800000	13999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	14000000	14199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	14200000	14399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	14400000	14599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	14600000	14799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	14800000	14999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	15000000	15199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	15200000	15399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	15400000	15599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	15600000	15799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	15800000	15999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	16000000	16199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	16200000	16399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	16400000	16599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	16600000	16799999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	16800000	16999999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	17000000	17199999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	17200000	17399999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	17400000	17599999	+	200kb_region	X
# Starting on region: CHROMOSOME_X	17600000	17718942	+	200kb_region	X
#        chromosome     start       rnd   region_type  chr_type  total_bases  \
# 0    CHROMOSOME_I         0    199999  200kb_region  Autosome        50182
# 1    CHROMOSOME_I    200000    399999  200kb_region  Autosome        54895
# 2    CHROMOSOME_I    400000    599999  200kb_region  Autosome        44890
# 3    CHROMOSOME_I    600000    799999  200kb_region  Autosome        15982
# 4    CHROMOSOME_I    800000    999999  200kb_region  Autosome        39344
# ..            ...       ...       ...           ...       ...          ...
# 499  CHROMOSOME_X  16800000  16999999  200kb_region         X        63892
# 500  CHROMOSOME_X  17000000  17199999  200kb_region         X        52920
# 501  CHROMOSOME_X  17200000  17399999  200kb_region         X        71861
# 502  CHROMOSOME_X  17400000  17599999  200kb_region         X        32652
# 503  CHROMOSOME_X  17600000  17718942  200kb_region         X        13502
#
#      total_m6A  m6A_frac  norm_m6A_frac                 condition
# 0        26265  0.523395       1.096356  N2 Young; 2uM Hia5 30min
# 1        27904  0.508316       1.064770  N2 Young; 2uM Hia5 30min
# 2        20097  0.447694       0.937786  N2 Young; 2uM Hia5 30min
# 3         8526  0.533475       1.117471  N2 Young; 2uM Hia5 30min
# 4        21623  0.549588       1.151223  N2 Young; 2uM Hia5 30min
# ..         ...       ...            ...                       ...
# 499      29191  0.456880       0.957028  N2 Young; 2uM Hia5 30min
# 500      21788  0.411716       0.862422  N2 Young; 2uM Hia5 30min
# 501      40261  0.560262       1.173582  N2 Young; 2uM Hia5 30min
# 502      14043  0.430081       0.900891  N2 Young; 2uM Hia5 30min
# 503       6268  0.464228       0.972418  N2 Young; 2uM Hia5 30min
#
# [504 rows x 10 columns]

# %%
### Build dataframe for plotting
filenames = ["/Data1/seq_data/Tube4_b2_2uM-Hia5_fiber-seq_11_21_22/basecalls/m6A_frac1_200kb_region.csv",
             "/Data1/seq_data/TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22/basecalls/m6A/m6A_frac1_200kb_region.csv",
             "/Data1/seq_data/TubeH1_021_SDC2-AIDpAux_Hia5_MSssI_12_19/basecalls/m6A/m6A_frac1_200kb_region.csv",
            "/Data1/seq_data/TubeT_N2_Young_FiberSeq_02_14_23_v3/basecalls/m6A/m6A_frac1_200kb_region.csv"]

df_list = []
combined_regions = []

# Loop through the list of file names
for filename in filenames:
    # Read each file into a dataframe
    df = pd.read_csv(filename)
    # Add the dataframe to the list of dataframes
    df_list.append(df)

# Concatenate the list of dataframes into a single dataframe
combined_regions = pd.concat(df_list)
print(combined_regions)
# Out:
#        chromosome     start       rnd   region_type  chr_type  total_bases  \
# 0    CHROMOSOME_I         0    199999  200kb_region  Autosome       350963
# 1    CHROMOSOME_I    200000    399999  200kb_region  Autosome       315559
# 2    CHROMOSOME_I    400000    599999  200kb_region  Autosome       359174
# 3    CHROMOSOME_I    600000    799999  200kb_region  Autosome       254909
# 4    CHROMOSOME_I    800000    999999  200kb_region  Autosome       282301
# ..            ...       ...       ...           ...       ...          ...
# 499  CHROMOSOME_X  16800000  16999999  200kb_region         X        63892
# 500  CHROMOSOME_X  17000000  17199999  200kb_region         X        52920
# 501  CHROMOSOME_X  17200000  17399999  200kb_region         X        71861
# 502  CHROMOSOME_X  17400000  17599999  200kb_region         X        32652
# 503  CHROMOSOME_X  17600000  17718942  200kb_region         X        13502
#
#      total_m6A  m6A_frac  norm_m6A_frac                 condition
# 0       187450  0.534102       1.000295       N2; 2uM Hia5 120min
# 1       157940  0.500509       0.937380       N2; 2uM Hia5 120min
# 2       195234  0.543564       1.018016       N2; 2uM Hia5 120min
# 3       136714  0.536325       1.004458       N2; 2uM Hia5 120min
# 4       165152  0.585021       1.095659       N2; 2uM Hia5 120min
# ..         ...       ...            ...                       ...
# 499      29191  0.456880       0.957028  N2 Young; 2uM Hia5 30min
# 500      21788  0.411716       0.862422  N2 Young; 2uM Hia5 30min
# 501      40261  0.560262       1.173582  N2 Young; 2uM Hia5 30min
# 502      14043  0.430081       0.900891  N2 Young; 2uM Hia5 30min
# 503       6268  0.464228       0.972418  N2 Young; 2uM Hia5 30min
#
# [2016 rows x 10 columns]

# %%
#source: https://stackoverflow.com/questions/67505252/plotly-box-p-value-significant-annotation
def add_p_value_annotation(fig, array_columns, subplot=None, _format=dict(interline=0.07, text_height=1.07, color='black')):
    ''' Adds notations giving the p-value between two box plot data (t-test two-sided comparison)
    
    Parameters:
    ----------
    fig: figure
        plotly boxplot figure
    array_columns: np.array
        array of which columns to compare 
        e.g.: [[0,1], [1,2]] compares column 0 with 1 and 1 with 2
    subplot: None or int
        specifies if the figures has subplots and what subplot to add the notation to
    _format: dict
        format characteristics for the lines

    Returns:
    -------
    fig: figure
        figure with the added notation
    '''
    # Specify in what y_range to plot for each pair of columns
    y_range = np.zeros([len(array_columns), 2])
    for i in range(len(array_columns)):
        y_range[i] = [1.01+i*_format['interline'], 1.02+i*_format['interline']]

    # Get values from figure
    fig_dict = fig.to_dict()

    # Get indices if working with subplots
    if subplot:
        if subplot == 1:
            subplot_str = ''
        else:
            subplot_str =str(subplot)
        indices = [] #Change the box index to the indices of the data for that subplot
        for index, data in enumerate(fig_dict['data']):
            #print(index, data['xaxis'], 'x' + subplot_str)
            if data['xaxis'] == 'x' + subplot_str:
                indices = np.append(indices, index)
        indices = [int(i) for i in indices]
        print((indices))
    else:
        subplot_str = ''

    # Print the p-values
    for index, column_pair in enumerate(array_columns):
        if subplot:
            data_pair = [indices[column_pair[0]], indices[column_pair[1]]]
        else:
            data_pair = column_pair

        # Mare sure it is selecting the data and subplot you want
        #print('0:', fig_dict['data'][data_pair[0]]['name'], fig_dict['data'][data_pair[0]]['xaxis'])
        #print('1:', fig_dict['data'][data_pair[1]]['name'], fig_dict['data'][data_pair[1]]['xaxis'])

        # Get the p-value
        pvalue = stats.ttest_ind(
            fig_dict['data'][data_pair[0]]['y'],
            fig_dict['data'][data_pair[1]]['y'],
            equal_var=False,
        )[1]
        if pvalue >= 0.05:
            symbol = 'ns'
        elif pvalue >= 0.01: 
            symbol = '*'
        elif pvalue >= 0.001:
            symbol = '**'
        else:
            symbol = '***'
        # Vertical line
        fig.add_shape(type="line",
            xref="x"+subplot_str, yref="y"+subplot_str+" domain",
            x0=column_pair[0], y0=y_range[index][0], 
            x1=column_pair[0], y1=y_range[index][1],
            line=dict(color=_format['color'], width=2,)
        )
        # Horizontal line
        fig.add_shape(type="line",
            xref="x"+subplot_str, yref="y"+subplot_str+" domain",
            x0=column_pair[0], y0=y_range[index][1], 
            x1=column_pair[1], y1=y_range[index][1],
            line=dict(color=_format['color'], width=2,)
        )
        # Vertical line
        fig.add_shape(type="line",
            xref="x"+subplot_str, yref="y"+subplot_str+" domain",
            x0=column_pair[1], y0=y_range[index][0], 
            x1=column_pair[1], y1=y_range[index][1],
            line=dict(color=_format['color'], width=2,)
        )
        ## add text at the correct x, y coordinates
        ## for bars, there is a direct mapping from the bar number to 0, 1, 2...
        fig.add_annotation(dict(font=dict(color=_format['color'],size=14),
            x=(column_pair[0] + column_pair[1])/2,
            y=y_range[index][1]*_format['text_height'],
            showarrow=False,
            text=symbol,
            textangle=0,
            xref="x"+subplot_str,
            yref="y"+subplot_str+" domain"
        ))
    return fig

# %%
# Plot the boxplot
marker_colors =["#c45746","#16415e"]

tube4_df = combined_regions.loc[combined_regions['condition']=="N2; 2uM Hia5 120min"]
tubeD_df = combined_regions.loc[combined_regions['condition']=="N2; 2uM Hia5 30min"]
tubeH_df = combined_regions.loc[combined_regions['condition']=="AID::SDC-2 + Auxin; 2uM Hia5 30min"]
tubeT_df = combined_regions.loc[combined_regions['condition']=="N2 Young; 2uM Hia5 30min"]


#fig=go.Figure()
# Source for subplot schema: https://stackoverflow.com/questions/55698429/different-box-plot-series-traces-within-plotly-subplots
# Tube 4
chr_type = "Autosome"
df_plot=tube4_df.loc[tube4_df['chr_type']==chr_type]
trace0 = go.Box(x=df_plot['condition']+" ", y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[0])

chr_type = "X"
df_plot=tube4_df.loc[tube4_df['chr_type']==chr_type]
trace1 = go.Box(x=df_plot['condition'], y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[1])

# Tube D
chr_type = "Autosome"
df_plot=tubeD_df.loc[tubeD_df['chr_type']==chr_type]
trace2 = go.Box(x=df_plot['condition']+" ", y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[0])

chr_type = "X"
df_plot=tubeD_df.loc[tubeD_df['chr_type']==chr_type]
trace3 = go.Box(x=df_plot['condition'], y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[1])

# Tube H
chr_type = "Autosome"
df_plot=tubeH_df.loc[tubeH_df['chr_type']==chr_type]
trace4 = go.Box(x=df_plot['condition']+" ", y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[0])

chr_type = "X"
df_plot=tubeH_df.loc[tubeH_df['chr_type']==chr_type]
trace5 = go.Box(x=df_plot['condition'], y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[1])

# Tube T
chr_type = "Autosome"
df_plot=tubeT_df.loc[tubeT_df['chr_type']==chr_type]
trace6 = go.Box(x=df_plot['condition']+" ", y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[0])

chr_type = "X"
df_plot=tubeT_df.loc[tubeT_df['chr_type']==chr_type]
trace7 = go.Box(x=df_plot['condition'], y=df_plot['norm_m6A_frac'],
                     notched=True,
                     name=chr_type, marker_color =marker_colors[1])

fig = make_subplots(rows=1, cols=4,
                    y_title = "m6A/A (normalized to average Autosome)",
                    shared_yaxes=True,
                    subplot_titles=("N2; <br> 2uM Hia5 120min", 
                                    "N2; <br> 2uM Hia5 30min", 
                                    "AID::SDC-2 + Auxin; <br> 2uM Hia5 30min",
                                    "N2 Young; <br> 2uM Hia5 30min"))
fig.append_trace(trace0, row = 1, col = 1)
fig.append_trace(trace1, row = 1, col = 1)
fig.append_trace(trace2, row = 1, col = 2)
fig.append_trace(trace3, row = 1, col = 2)
fig.append_trace(trace4, row = 1, col = 3)
fig.append_trace(trace5, row = 1, col = 3)
fig.append_trace(trace6, row = 1, col = 4)
fig.append_trace(trace7, row = 1, col = 4)
fig = add_p_value_annotation(fig, [[0,1]],0)
fig = add_p_value_annotation(fig, [[0,1]],2)
fig = add_p_value_annotation(fig, [[0,1]],3)
fig = add_p_value_annotation(fig, [[0,1]],4)
fig.update_yaxes(dtick=0.05)
fig.layout.annotations[0].update(y=-0.1)
fig.layout.annotations[1].update(y=-0.1)
fig.layout.annotations[2].update(y=-0.1)
fig.layout.annotations[3].update(y=-0.1)
fig['layout'].update(height = 600)
fig.update_layout(template="plotly_white")
fig.update_xaxes(showticklabels=False)
fig.update_yaxes(range=[0.75, 1.4])
    
#fig.update_layout(boxmode='group', xaxis_tickangle=0)
fig.show()
# Out:
# [2, 3]
# [4, 5]
# [6, 7]
# <div>                            <div id="91f09bd8-fac3-458d-a4b3-3dff43481a2a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91f09bd8-fac3-458d-a4b3-3dff43481a2a")) {                    Plotly.newPlot(                        "91f09bd8-fac3-458d-a4b3-3dff43481a2a",                        [{"marker":{"color":"#c45746"},"name":"Autosome","notched":true,"x":["N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ","N2; 2uM Hia5 120min ...
