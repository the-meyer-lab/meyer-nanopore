# %%
# Code that reads in nucleosome positions and performs NRL analysis

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import seaborn as sns
import plotly.express as px
from sklearn.linear_model import LinearRegression # for linear regression analysis
from scipy.signal import find_peaks # For finding peaks in distribtion
#sns.set_style('darkgrid')

# %%
### Import dataframes
# Import nucleosome positions
# Nucleosome cutoff = 9
nucleosome_positions_D = pd.read_csv("/Data1/seq_data/TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22/wig/output/result_m6A_9/pooled/Data1_seq_data_TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22_wig_output_D_modified_bases.6mA.merged_strand_Hnorm_10SCALE.smooth.positions.xls", delimiter="\t")
nucleosome_positions_H = pd.read_csv("/Data1/seq_data/TubeH1_021_SDC2-AIDpAux_Hia5_MSssI_12_19/wig/output/result_m6A_9/pooled/Data1_seq_data_TubeH1_021_SDC2-AIDpAux_Hia5_MSssI_12_19_wig_output_H_modified_bases.6mA.merged_strand_NOnorm_10SCALE.smooth.positions.xls", delimiter="\t")

# Nucleosome cutoff = 10
#nucleosome_positions_D = pd.read_csv("/Data1/seq_data/TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22/wig/output/result_m6a_10/pooled/Data1_seq_data_TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22_wig_output_D_modified_bases.6mA.merged_strand_Hnorm_10SCALE.smooth.positions.xls", delimiter="\t")
#nucleosome_positions_H = pd.read_csv("/Data1/seq_data/TubeH1_021_SDC2-AIDpAux_Hia5_MSssI_12_19/wig/output/result_m6a_10/pooled/Data1_seq_data_TubeH1_021_SDC2-AIDpAux_Hia5_MSssI_12_19_wig_output_H_modified_bases.6mA.merged_strand_NOnorm_10SCALE.smooth.positions.xls", delimiter="\t")
display(nucleosome_positions_D.head(1))

# Import bed file
bed_raw = pd.read_csv("/Data1/reference/tss_tes_rex_combined.bed", delimiter="\t")
bed_raw = bed_raw.drop(columns=["chr-type"])
display('bed_raw:',bed_raw.head(1))
display(bed_raw.type.unique())
bed_tss = bed_raw[bed_raw['type'].str.startswith('TSS')]
display('bed_tss:',bed_tss.head(1))

bed_rex = bed_raw[bed_raw['type'].str.endswith('rex')]
display('bed_rex:',bed_rex.head(1))
# Out:
#             chr  start   end  smt_pos  smt_value  fuzziness_score
# 0  CHROMOSOME_I   4561  4701     4631       9.66        56.633691
# 'bed_raw:'
#      chromosome     start       end strand        type
# 0  CHROMOSOME_X  14525402  14525404      +  strong_rex
# array(['strong_rex', 'weak_rex', 'TSS_q4', 'TSS_q3', 'TSS_q2', 'TSS_q1',
#        'TES_q4', 'TES_q3', 'TES_q2', 'TES_q1', 'whole_chr',
#        '200kb_region', '50kb_region', 'mex_motif', 'mexII_motif'],
#       dtype=object)
# 'bed_tss:'
#       chromosome     start       end strand    type
# 40  CHROMOSOME_V  15065272  15065272      +  TSS_q4
# 'bed_rex:'
#      chromosome     start       end strand        type
# 0  CHROMOSOME_X  14525402  14525404      +  strong_rex

# %%
### CONFIGURATIONS
n_dist = 10 #n+X to consider

def frequency_table(df):
    global n_dist
    frequency_df = pd.DataFrame(columns=["chr", "dist","n-plus",'smt_pos'])
    column_labels =[]
    
    for i in range(1, n_dist+1):
    #create list of column labels and assign them to a new df, based on the number of n+ to consider.
        column_label=(str(i))
        column_labels.append(column_label)
        df = df.assign(**{column_label: df['smt_pos'].diff(periods=i)})
        # Create an empty list to store the tuples for the new dataframe
    data = []

    # Iterate through the columns of the original dataframe
    for col in df[column_labels]:
        # Get the values for the current column
        values = df[col].values
        chr_values = df["chr"].values
        smt_pos = df["smt_pos"].values
    # Create a tuple for each value with the column name as the first element and the value as the second element
        for chr_val, val, smt_pos in zip(chr_values,values,smt_pos):
            data.append((chr_val,col,val,smt_pos))

    # Create the new dataframe using the list of tuples
    frequency_df = pd.DataFrame(data, columns=['chr','n-plus', 'dist','smt_pos'])
    frequency_df = frequency_df.dropna()
    frequency_df = frequency_df[frequency_df['dist'] > 0]
    
    for i in range(1,100):
        max_val = frequency_df['dist'].max()
        frequency_df = frequency_df[frequency_df['dist'] != max_val]
    
    frequency_df['n-plus'] = frequency_df['n-plus'].astype(int)
    #frequency_df["nrl"] = frequency_df["dist"]/frequency_df["n-plus"]
    
    
    # get the values of the 'pos' column as a numpy array
    return frequency_df

frequency_df_D = frequency_table(nucleosome_positions_D)
frequency_df_H = frequency_table(nucleosome_positions_H)


display(frequency_df_D.tail(10))     
display(frequency_df_H.head(10))

#frequency_df_D.to_csv("/Data1/seq_data/TubeD1a_N2_Fiberseq_Hia5_MSssI_12_22_22/wig/output/result_m6a_10/pooled/D_nrl.csv",index=False,)
#frequency_df_H = frequency_table(nucleosome_positions_H)
# Out:
#                   chr  n-plus    dist   smt_pos
# 3111860  CHROMOSOME_X      10  4630.0  17712191
# 3111861  CHROMOSOME_X      10  4500.0  17712311
# 3111862  CHROMOSOME_X      10  5540.0  17713451
# 3111863  CHROMOSOME_X      10  5760.0  17713851
# 3111864  CHROMOSOME_X      10  5640.0  17713981
# 3111865  CHROMOSOME_X      10  7040.0  17715911
# 3111866  CHROMOSOME_X      10  6560.0  17716071
# 3111867  CHROMOSOME_X      10  6650.0  17716401
# 3111868  CHROMOSOME_X      10  8130.0  17718271
# 3111869  CHROMOSOME_X      10  8130.0  17718661
#              chr  n-plus   dist  smt_pos
# 1   CHROMOSOME_I       1  510.0      971
# 2   CHROMOSOME_I       1  120.0     1091
# 3   CHROMOSOME_I       1  330.0     1421
# 4   CHROMOSOME_I       1  140.0     1561
# 5   CHROMOSOME_I       1  230.0     1791
# 6   CHROMOSOME_I       1  300.0     2091
# 7   CHROMOSOME_I       1  230.0     2321
# 8   CHROMOSOME_I       1  110.0     2431
# 9   CHROMOSOME_I       1  150.0     2581
# ...

# %%
### Create data subsets for plotting
frequency_df_D['genotype'] = 'N2'
frequency_df_H['genotype'] = 'AID-SDC2 + Aux'
data = pd.concat([frequency_df_D, frequency_df_H])
data['chr-type'] = data['chr'].apply(lambda x: 'X' if x == 'CHROMOSOME_X' else 'A')

data_x=data[data['chr']=='CHROMOSOME_X']
data_a=data[data['chr']!='CHROMOSOME_X']
data_D=data[data['genotype']=='N2']
data_H=data[data['genotype']!='N2']

#fig = sns.displot(data_D, x="dist", hue="chr-type", kde=True, cut=0)
data_D_crop=data_D[data_D['dist']<2200]
data_H_crop=data_H[data_H['dist']<2200]

### Histograms, break out into X and A for separate plotting
D_X = data_D_crop.loc[data_D_crop['chr-type']=='X']
D_A = data_D_crop.loc[data_D_crop['chr-type']=='A']
H_X = data_H_crop.loc[data_H_crop['chr-type']=='X']
H_A = data_H_crop.loc[data_H_crop['chr-type']=='A']

# %%
sns.reset_defaults()
size = (8,12)
### TUBE D PLOT
### Tube D, Chromosome X "#c45746","#16415e"
fig = sns.displot(D_X, x="dist", color="#c45746", label="X", kind="kde",cut=-0.5,height=6,aspect=1.5,linewidth = 3)
plt.title('N2 30min Hia5 Treatment\nChromosome X Nucleosome-Nucleosome Distance', fontsize=15)
#sns.histplot(D_X, x="dist", color="#61a661", label="X",kde=True, binwidth=10, stat = "percent").set(title='N2 Nucleosome-Nucleosome Distance')
ax1 = fig.facet_axis(0,0)
ax1.set_xlim(0,1500)
ax1.set_ylim(0.00045,)

### NRL CALCULATION
### Tube D, Chromosome X
Xline_x = ax1.lines[0].get_xdata() # Get the x data of the distribution
Xline_y = ax1.lines[0].get_ydata() # Get the y data of the distribution
Xpeaks_index = find_peaks(Xline_y)
peak_number = numpy.array(range(1, len(Xpeaks_index[0])+1))
Xpeaks_x = [Xline_x[i] for i in Xpeaks_index[0]]
Xpeaks = pd.DataFrame({'x': peak_number, 'y': Xpeaks_x})
Xpeaks.drop(Xpeaks.tail(len(peak_number)-7).index,inplace=True)
inc=0
for i, _x in enumerate(Xpeaks['y']):
    inc+=1
    # add a vertical line for the value
    ax1.axvline(x=_x,lw=1,ls=":",color='grey')
    # add a label below the line
    ax1.text(_x, 0.000465 , str(int(_x)), ha='center',fontsize=10)
    ax1.text(_x, 0.00047 , "N+"+str(inc), ha='center',fontsize=10)
ax1.legend(loc="best")
plt.xlabel('nucleosome-nucleosome distance (bp)', fontsize=12)
fig.savefig('jupyter_output/N2_30min_NRL_X.png',dpi=300,bbox_inches='tight')
fig.savefig('jupyter_output/N2_30min_NRL_X.svg',bbox_inches='tight')

fig2 = sns.displot(D_A, x="dist", color="#16415e", label="Autosome", kind="kde",cut=-0.5,height=6,aspect=1.5,linewidth = 3)
plt.title('N2 30min Hia5 Treatment\nAutosome Nucleosome-Nucleosome Distance', fontsize=15)
ax2 = fig2.facet_axis(0,0)
### Tube D, Autosomes
#sns.histplot(D_A, x="dist", color="#ae64ad",label="A", kde=True, binwidth=10, stat = "percent")
#plt.tick_params(axis='both', which='major', labelsize=14)
ax2.legend(loc="best")
ax2.set_xlim(0,1500)
ax2.set_ylim(0.00045,)

### Tube D, Autosomes
Aline_x = ax2.lines[0].get_xdata() # Get the x data of the distribution
Aline_y = ax2.lines[0].get_ydata() # Get the y data of the distribution
Apeaks_index = find_peaks(Aline_y)
peak_number = numpy.array(range(1, len(Xpeaks_index[0])+1))
Apeaks_x = [Aline_x[i] for i in Apeaks_index[0]]
Apeaks = pd.DataFrame({'x': peak_number, 'y': Apeaks_x})
Apeaks.drop(Apeaks.tail(len(peak_number)-7).index,inplace=True)
inc=0
for i, _x in enumerate(Apeaks['y']):
    inc+=1
    # add a vertical line for the value
    ax2.axvline(x=_x,lw=1,ls=":",color='grey')
    # add a label below the line
    ax2.text(_x, 0.000465 , str(int(_x)), ha='center',fontsize=10)
    ax2.text(_x, 0.00047 , "N+"+str(inc), ha='center',fontsize=10)
plt.xlabel('nucleosome-nucleosome distance (bp)', fontsize=12)
fig2.savefig('jupyter_output/N2_30min_NRL_A.png',dpi=300,bbox_inches='tight')
fig2.savefig('jupyter_output/N2_30min_NRL_A.svg',bbox_inches='tight')
plt.show()

D_NRL = Xpeaks.merge(Apeaks, on='x')
D_NRL = D_NRL.rename(columns={'x':'peak-number','y_x': 'X-peak-position', 'y_y': 'A-peak-position'})
display(D_NRL)
# Out:
#    peak-number  X-peak-position  A-peak-position
# 0            1       184.836928       168.792348
# 1            2       359.866577       355.498567
# 2            3       534.896227       531.832219
# 3            4       709.925876       708.165871
# 4            5       915.843111       894.872090
# 5            6      1101.168622      1071.205742
# 6            7      1276.198272      1257.911961

# %%
size = (8,12)
### TUBE H PLOT
### Tube H, Chromosome X
fig = sns.displot(H_X, x="dist", color="#c45746", label="X", kind="kde",cut=-0.5,height=6,aspect=1.5,linewidth = 3).set(title='AID::SDC-2 Nucleosome-Nucleosome Distance')
#sns.histplot(H_X, x="dist", color="#61a661", label="X",kde=True, binwidth=10, stat = "percent").set(title='N2 Nucleosome-Nucleosome Histance')
plt.title('AID::SDC-2 30min Hia5 Treatment\nChromosome X Nucleosome-Nucleosome Distance', fontsize=15)
ax1 = fig.facet_axis(0,0)
ax1.set_xlim(0,1500)
ax1.set_ylim(0.00045,)

### NRL CALCULATION
### Tube H, Chromosome X
Xline_x = ax1.lines[0].get_xdata() # Get the x data of the distribution
Xline_y = ax1.lines[0].get_ydata() # Get the y data of the distribution
Xpeaks_index = find_peaks(Xline_y)
peak_number = numpy.array(range(1, len(Xpeaks_index[0])+1))
Xpeaks_x = [Xline_x[i] for i in Xpeaks_index[0]]
Xpeaks = pd.DataFrame({'x': peak_number, 'y': Xpeaks_x})
Xpeaks.drop(Xpeaks.tail(len(peak_number)-7).index,inplace=True)
inc=0
for i, _x in enumerate(Xpeaks['y']):
    inc+=1
    # add a vertical line for the value
    ax1.axvline(x=_x,lw=1,ls=":",color='grey')
    # add a label below the line
    ax1.text(_x, 0.000465 , str(int(_x)), ha='center',fontsize=10)
    ax1.text(_x, 0.00047 , "N+"+str(inc), ha='center',fontsize=10)
plt.xlabel('nucleosome-nucleosome distance (bp)', fontsize=12)
ax1.legend(loc="best")

fig.savefig('jupyter_output/AID-SDC2_30min_NRL_X.png',dpi=300,bbox_inches='tight')
fig.savefig('jupyter_output/AID-SDC2_30min_NRL_X.svg',bbox_inches='tight')

fig2 = sns.displot(H_A, x="dist", color="#16415e", label="Autosome", kind="kde",cut=-0.5,height=6,aspect=1.5,linewidth = 3)
plt.title('AID::SDC-2 30min Hia5 Treatment\nAutosome Nucleosome-Nucleosome Distance', fontsize=15)
ax2 = fig2.facet_axis(0,0)
### Tube H, Autosomes
#sns.histplot(H_A, x="dist", color="#ae64ad",label="A", kde=True, binwidth=10, stat = "percent")
#plt.tick_params(axis='both', which='major', labelsize=14)
ax2.legend(loc="best")
ax2.set_xlim(0,1500)
ax2.set_ylim(0.00045,)

### Tube H, Autosomes
Aline_x = ax2.lines[0].get_xdata() # Get the x data of the distribution
Aline_y = ax2.lines[0].get_ydata() # Get the y data of the distribution
Apeaks_index = find_peaks(Aline_y)
peak_number = numpy.array(range(1, len(Xpeaks_index[0])+1))
Apeaks_x = [Aline_x[i] for i in Apeaks_index[0]]
Apeaks = pd.DataFrame({'x': peak_number, 'y': Apeaks_x})
Apeaks.drop(Apeaks.tail(len(peak_number)-7).index,inplace=True)
inc=0
for i, _x in enumerate(Apeaks['y']):
    inc+=1
    # add a vertical line for the value
    ax2.axvline(x=_x,lw=1,ls=":",color='grey')
    # add a label below the line
    ax2.text(_x, 0.000465 , str(int(_x)), ha='center',fontsize=10)
    ax2.text(_x, 0.00047 , "N+"+str(inc), ha='center',fontsize=10)
plt.xlabel('nucleosome-nucleosome distance (bp)', fontsize=12)
fig2.savefig('jupyter_output/AID-SDC2_30min_NRL_A.png',dpi=300,bbox_inches='tight')
fig2.savefig('jupyter_output/AID-SDC2_30min_NRL_A.svg',bbox_inches='tight')
plt.show()

H_NRL = Xpeaks.merge(Apeaks, on='x')
H_NRL = H_NRL.rename(columns={'x':'peak-number','y_x': 'X-peak-position', 'y_y': 'A-peak-position'})
display(H_NRL)
# Out:
#    peak-number  X-peak-position  A-peak-position
# 0            1       184.348871       168.112333
# 1            2       359.739985       354.948079
# 2            3       535.131100       531.404061
# 3            4       710.522214       728.619571
# 4            5       896.230453       905.075554
# 5            6      1081.938692      1081.531536
# 6            7      1277.964055      1268.367282

# %%
# Fit a linear regression model
model = LinearRegression()
model.fit(D_NRL['peak-number'].to_frame('peak-number'), 
          D_NRL['X-peak-position'].to_frame('X-peak-position'))
DslopeX = model.coef_[0].round(2)
DinterceptX = model.intercept_.round(2)
DequationX = f'X NRL: {DslopeX}'
print("DequationX;",DequationX)

model = LinearRegression()
model.fit(D_NRL['peak-number'].to_frame('peak-number'), 
          D_NRL['A-peak-position'].to_frame('A-peak-position'))
DslopeA = model.coef_[0].round(1)
DinterceptA = model.intercept_.round(1)
DequationA = f'A NRL: {DslopeA}'
print("DequationA;",DequationA)

# Fit a linear regression model
model = LinearRegression()
model.fit(H_NRL['peak-number'].to_frame('peak-number'), 
          H_NRL['X-peak-position'].to_frame('X-peak-position'))
HslopeX = model.coef_[0].round(1)
HinterceptX = model.intercept_.round(1)
HequationX = f'X NRL: {HslopeX}'
print("HequationX;",HequationX)

model = LinearRegression()
model.fit(H_NRL['peak-number'].to_frame('peak-number'), 
          H_NRL['A-peak-position'].to_frame('A-peak-position'))
HslopeA = model.coef_[0].round(1)
HinterceptA = model.intercept_.round(1)
HequationA = f'A NRL: {HslopeA}'
print("HequationA;",HequationA)
# Out:
# DequationX; X NRL: [183.49]
# DequationA; A NRL: [180.8]
# HequationX; X NRL: [181.7]
# HequationA; A NRL: [183.1]

# %%
fig, ax = plt.subplots()

### Linear Regression for Nucleosome Repeat Length
sns.regplot(x='peak-number', y='X-peak-position', data=D_NRL,ax=ax,label = 'chrX',color="#c45746").set(title='N2 Nucleosome Repeat Length')
sns.regplot(x='peak-number', y='A-peak-position', data=D_NRL,ax=ax,label = 'Autosomes',color="#16415e")
# Add the equation of the linear regression to the plot
ax.legend(loc="best")
plt.text(0.5, 0.2, DequationX, ha='center', va='center', transform=ax.transAxes,color="#c45746")
plt.text(0.5, 0.8, DequationA, ha='center', va='center', transform=ax.transAxes,color="#16415e")
plt.ylabel('nucleosome-nucleosome distance (bp)', fontsize=12)
plt.xlabel('peak number (N+)', fontsize=12)
fig.savefig('jupyter_output/N2_30min_NRL_trend.png',dpi=300,bbox_inches='tight')
fig.savefig('jupyter_output/N2_30min_NRL_trend.svg',bbox_inches='tight')
plt.show()

fig, ax = plt.subplots()

### Linear Regression for Nucleosome Repeat Length
sns.regplot(x='peak-number', y='X-peak-position', data=H_NRL,ax=ax,label = 'chrX',color="#c45746").set(title='AID::SDC-2 Nucleosome Repeat Length')
sns.regplot(x='peak-number', y='A-peak-position', data=H_NRL,ax=ax,label = 'Autosomes',color="#16415e")
# Add the equation of the linear regression to the plot
ax.legend(loc="best")
plt.text(0.5, 0.2, HequationX, ha='center', va='center', transform=ax.transAxes,color="#c45746")
plt.text(0.5, 0.8, HequationA, ha='center', va='center', transform=ax.transAxes,color="#16415e")
plt.ylabel('nucleosome-nucleosome distance (bp)', fontsize=12)
plt.xlabel('peak number (N+)', fontsize=12)
fig.savefig('jupyter_output/AID-SDC2_30min_NRL_trend.png',dpi=300,bbox_inches='tight')
fig.savefig('jupyter_output/AID-SDC2_30min_NRL_trend.svg',bbox_inches='tight')
plt.show()

# %%
region_cutoff = 1500
### Dataframes for TSS specific analysis

D_X_tss = pd.DataFrame(columns=D_X.columns)
for chrm in D_X.chr.unique():
    bed_tss_chrm = bed_tss.loc[bed_tss['chromosome'] == chrm]
    bed_tss_chrm = bed_tss_chrm.sort_values(by="start")
    D_X_tss_chrm = D_X.loc[D_X['chr'] == chrm]
    D_X_tss_chrm = D_X_tss_chrm.sort_values(by="smt_pos")
    D_X_tss_chrm = pd.merge_asof(
        D_X_tss_chrm,
        bed_tss_chrm, 
        left_on='smt_pos',
        right_on='start')
    D_X_tss_chrm['sub']=abs(D_X_tss_chrm['smt_pos']-D_X_tss_chrm['start'])
    D_X_tss_chrm=D_X_tss_chrm.loc[D_X_tss_chrm['sub'] < region_cutoff]
    D_X_tss_chrm = D_X_tss_chrm.iloc[:,:-len(bed_tss.columns)-1]
    D_X_tss = D_X_tss.append(D_X_tss_chrm)
    D_X_tss = D_X_tss.reset_index(drop=True)

D_A_tss = pd.DataFrame(columns=D_A.columns)
for chrm in D_A.chr.unique():
    bed_tss_chrm = bed_tss.loc[bed_tss['chromosome'] == chrm]
    bed_tss_chrm = bed_tss_chrm.sort_values(by="start")
    D_A_tss_chrm = D_A.loc[D_A['chr'] == chrm]
    D_A_tss_chrm = D_A_tss_chrm.sort_values(by="smt_pos")
    D_A_tss_chrm = pd.merge_asof(
        D_A_tss_chrm,
        bed_tss_chrm, 
        left_on='smt_pos',
        right_on='start')
    D_A_tss_chrm['sub']=abs(D_A_tss_chrm['smt_pos']-D_A_tss_chrm['start'])
    D_A_tss_chrm=D_A_tss_chrm.loc[D_A_tss_chrm['sub'] < region_cutoff]
    D_A_tss_chrm = D_A_tss_chrm.iloc[:,:-len(bed_tss.columns)-1]
    D_A_tss = D_A_tss.append(D_A_tss_chrm)
    D_A_tss=D_A_tss.reset_index(drop=True)

H_X_tss = pd.DataFrame(columns=H_X.columns)
for chrm in H_X.chr.unique():
    bed_tss_chrm = bed_tss.loc[bed_tss['chromosome'] == chrm]
    bed_tss_chrm = bed_tss_chrm.sort_values(by="start")
    H_X_tss_chrm = H_X.loc[H_X['chr'] == chrm]
    H_X_tss_chrm = H_X_tss_chrm.sort_values(by="smt_pos")
    H_X_tss_chrm = pd.merge_asof(
        H_X_tss_chrm,
        bed_tss_chrm, 
        left_on='smt_pos',
        right_on='start')
    H_X_tss_chrm['sub']=abs(H_X_tss_chrm['smt_pos']-H_X_tss_chrm['start'])
    H_X_tss_chrm=H_X_tss_chrm.loc[H_X_tss_chrm['sub'] < region_cutoff]
    H_X_tss_chrm = H_X_tss_chrm.iloc[:,:-len(bed_tss.columns)-1]
    H_X_tss = H_X_tss.append(H_X_tss_chrm)
    H_X_tss=H_X_tss.reset_index(drop=True)

H_A_tss = pd.DataFrame(columns=H_A.columns)
for chrm in H_A.chr.unique():
    bed_tss_chrm = bed_tss.loc[bed_tss['chromosome'] == chrm]
    bed_tss_chrm = bed_tss_chrm.sort_values(by="start")
    H_A_tss_chrm = H_A.loc[H_A['chr'] == chrm]
    H_A_tss_chrm = H_A_tss_chrm.sort_values(by="smt_pos")
    H_A_tss_chrm = pd.merge_asof(
        H_A_tss_chrm,
        bed_tss_chrm, 
        left_on='smt_pos',
        right_on='start')
    H_A_tss_chrm['sub']=abs(H_A_tss_chrm['smt_pos']-H_A_tss_chrm['start'])
    H_A_tss_chrm=H_A_tss_chrm.loc[H_A_tss_chrm['sub'] < region_cutoff]
    H_A_tss_chrm = H_A_tss_chrm.iloc[:,:-len(bed_tss.columns)-1]
    H_A_tss = H_A_tss.append(H_A_tss_chrm)
    H_A_tss=H_A_tss.reset_index(drop=True)

# %%
size=(12,6)
### TUBE D PLOT
### Tube D, Chromosome X
fig, ax = plt.subplots(figsize=size)
sns.histplot(D_X_tss, x="dist", color="skyblue", label="X",kde=True, binwidth=10, stat = "percent").set(title='N2 Nucleosome-Nucleosome Distance')

### Tube D, Autosomes
sns.histplot(D_A_tss, x="dist", color="red",label="A", kde=True, binwidth=10, stat = "percent")
plt.tick_params(axis='both', which='major', labelsize=14)
ax.set_xlim(0,1000)
ax.set_ylim(0.55,0.9)

plt.show()

### NRL CALCULATION
### Tube D, Chromosome X
Xline_x = ax.lines[0].get_xdata() # Get the x data of the distribution
Xline_y = ax.lines[0].get_ydata() # Get the y data of the distribution
Xpeaks_index = find_peaks(Xline_y)
peak_number = numpy.array(range(1, len(Xpeaks_index[0])+1))
Xpeaks_x = [Xline_x[i] for i in Xpeaks_index[0]]
Xpeaks = pd.DataFrame({'x': peak_number, 'y': Xpeaks_x})

### Tube D, Autosomes
Aline_x = ax.lines[1].get_xdata() # Get the x data of the distribution
Aline_y = ax.lines[1].get_ydata() # Get the y data of the distribution
Apeaks_index = find_peaks(Aline_y)
peak_number = numpy.array(range(1, len(Apeaks_index[0])+1))
Apeaks_x = [Aline_x[i] for i in Apeaks_index[0]]
Apeaks = pd.DataFrame({'x': peak_number, 'y': Apeaks_x})
D_NRL = Xpeaks.merge(Apeaks, on='x')
D_NRL = D_NRL.rename(columns={'x':'peak-number','y_x': 'X-peak-position', 'y_y': 'A-peak-position'})

# %%
### TUBE H PLOT
### Tube H, Chromosome X
fig, ax = plt.subplots(figsize=size)
sns.histplot(H_X_tss, x="dist", color="skyblue", label="X",kde=True, binwidth=10, stat = "percent").set(title='AID::SDC-2 Nucleosome-Nucleosome Distance')

### Tube H, Autosomes
sns.histplot(H_A_tss, x="dist", color="red",label="A", kde=True, binwidth=10, stat = "percent")
ax.set_xlim(0,1000)
ax.set_ylim(0.55,0.9)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.show()

### NRL CALCULATION

### Tube H, Chromosome X
Xline_x = ax.lines[0].get_xdata() # Get the x data of the distribution
Xline_y = ax.lines[0].get_ydata() # Get the y data of the distribution
Xpeaks_index = find_peaks(Xline_y)
peak_number = numpy.array(range(1, len(Xpeaks_index[0])+1))
print("Xpeaks_index",Xpeaks_index)
Xpeaks_x = [Xline_x[i] for i in Xpeaks_index[0]]
Xpeaks = pd.DataFrame({'x': peak_number, 'y': Xpeaks_x})

### Tube H, Autosomes
Aline_x = ax.lines[1].get_xdata() # Get the x data of the distribution
Aline_y = ax.lines[1].get_ydata() # Get the y data of the distribution
Apeaks_index = find_peaks(Aline_y)
print("Apeaks_index",Apeaks_index)
Apeaks_x = [Aline_x[i] for i in Apeaks_index[0]]
peak_number = numpy.array(range(1, len(Apeaks_index[0])+1))
Apeaks = pd.DataFrame({'x': peak_number, 'y': Apeaks_x})
H_NRL = Xpeaks.merge(Apeaks, on='x')
H_NRL = H_NRL.rename(columns={'x':'peak-number','y_x': 'X-peak-position', 'y_y': 'A-peak-position'})
# Out:
# Xpeaks_index (array([ 14,  36,  60,  88, 110, 147, 174]), {})
# Apeaks_index (array([ 10,  36,  64,  91, 114, 140, 162]), {})

# %%
# Fit a linear regression model
model = LinearRegression()
model.fit(D_NRL['peak-number'].to_frame('peak-number'), 
          D_NRL['X-peak-position'].to_frame('X-peak-position'))
DslopeX = model.coef_[0].round(2)
DinterceptX = model.intercept_.round(2)
DequationX = f'X NRL: {DslopeX}'
print("DequationX;",DequationX)

model = LinearRegression()
model.fit(D_NRL['peak-number'].to_frame('peak-number'), 
          D_NRL['A-peak-position'].to_frame('A-peak-position'))
DslopeA = model.coef_[0].round(1)
DinterceptA = model.intercept_.round(1)
DequationA = f'A NRL: {DslopeA}'
print("DequationA;",DequationA)

# Fit a linear regression model
model = LinearRegression()
model.fit(H_NRL['peak-number'].to_frame('peak-number'), 
          H_NRL['X-peak-position'].to_frame('X-peak-position'))
HslopeX = model.coef_[0].round(1)
HinterceptX = model.intercept_.round(1)
HequationX = f'X NRL: {HslopeX}'
print("HequationX;",HequationX)

model = LinearRegression()
model.fit(H_NRL['peak-number'].to_frame('peak-number'), 
          H_NRL['A-peak-position'].to_frame('A-peak-position'))
HslopeA = model.coef_[0].round(1)
HinterceptA = model.intercept_.round(1)
HequationA = f'A NRL: {HslopeA}'
print("HequationA;",HequationA)
# Out:
# DequationX; X NRL: [185.77]
# DequationA; A NRL: [176.5]
# HequationX; X NRL: [188.3]
# HequationA; A NRL: [179.1]

# %%
fig, ax = plt.subplots()

### Linear Regression for Nucleosome Repeat Length
sns.regplot(x='peak-number', y='X-peak-position', data=D_NRL,ax=ax,label = 'chrX',color="skyblue").set(title='N2 Nucleosome Repeat Length')
sns.regplot(x='peak-number', y='A-peak-position', data=D_NRL,ax=ax,label = 'Autosomes',color="red")
# Add the equation of the linear regression to the plot
ax.legend(loc="best")
plt.text(0.5, 0.2, DequationX, ha='center', va='center', transform=ax.transAxes,color="skyblue")
plt.text(0.5, 0.8, DequationA, ha='center', va='center', transform=ax.transAxes,color="red")
plt.show()

fig, ax = plt.subplots()

### Linear Regression for Nucleosome Repeat Length
sns.regplot(x='peak-number', y='X-peak-position', data=H_NRL,ax=ax,label = 'chrX',color="skyblue").set(title='AID::SDC-2 Nucleosome Repeat Length')
sns.regplot(x='peak-number', y='A-peak-position', data=H_NRL,ax=ax,label = 'Autosomes',color="red")
# Add the equation of the linear regression to the plot
ax.legend(loc="best")
plt.text(0.5, 0.2, HequationX, ha='center', va='center', transform=ax.transAxes,color="skyblue")
plt.text(0.5, 0.8, HequationA, ha='center', va='center', transform=ax.transAxes,color="red")
plt.show()

# %%
### OLD
def frequency_table(df):
    frequency_df = pd.DataFrame(columns=["chr", "dist","n-plus"])

    for index, row in df.head(100).iterrows():
        # Get the value of the "smt_pos" column for this row
        chrm = row["chr"]

        # Get the value of the "smt_pos" column for this row
        smt_pos = row["smt_pos"]

        # Get the next X rows of the dataframe
        next_rows = nucleosome_positions_D[index+1:index+n_dist+1]

        n_counter = 0
        # Subtract the "smt_pos" value from each of the next 10 rows
        for i, r in next_rows.iterrows():
            # If n'th row's chromosome, and current row's chromosome match:
            if r["chr"] == chrm:
                n_counter += 1
                # calculate nlr
                difference = int((r["smt_pos"] - smt_pos)/n_counter)
                # append to frequency table
                frequency_df = frequency_df.append({"chr": chrm, "dist": difference, "n-plus": n_counter}, ignore_index=True)

    # Sort the results_df dataframe by "smt_pos" and "difference"
    #frequency_df = frequency_df.sort_values(by=["chr", "dist","n-plus"])

    display(frequency_df.tail(20))
    return frequency_df


###
# Fit a linear regression model
model = LinearRegression()
model.fit(data_D[.loc[data_D['chr-type']=='X','n-plus']].to_frame('n-plus'), 
          data_D.loc[data_D['chr-type']=='X','dist'].to_frame('dist'))
DslopeX = model.coef_[0].round(2)
DinterceptX = model.intercept_.round(2)
DequationX = f'X: y = {DslopeX}x + {DinterceptX}'
print("DequationX;",DequationX)

model = LinearRegression()
model.fit(data_D.loc[data_D['chr-type']=='A','n-plus'].to_frame('n-plus'), 
          data_D.loc[data_D['chr-type']=='A','dist'].to_frame('dist'))
DslopeA = model.coef_[0].round(1)
DinterceptA = model.intercept_.round(1)
DequationA = f'A: y = {DslopeA}x + {DinterceptA}'
print("DequationA;",DequationA)

# Fit a linear regression model
model = LinearRegression()
model.fit(data_H.loc[data_H['chr-type']=='X','n-plus'].to_frame('n-plus'), 
          data_H.loc[data_H['chr-type']=='X','dist'].to_frame('dist'))
HslopeX = model.coef_[0].round(1)
HinterceptX = model.intercept_.round(1)
HequationX = f'X: y = {HslopeX}x + {HinterceptX}'
print("HequationX;",HequationX)

model = LinearRegression()
model.fit(data_H.loc[data_H['chr-type']=='A','n-plus'].to_frame('n-plus'), 
          data_H.loc[data_H['chr-type']=='A','dist'].to_frame('dist'))
HslopeA = model.coef_[0].round(1)
HinterceptA = model.intercept_.round(1)
HequationA = f'A: y = {HslopeA}x + {HinterceptA}'
print("HequationA;",HequationA)
